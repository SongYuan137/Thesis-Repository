# %%
import os
import shutil
import random
import keras
import tensorflow

classes_number = 4

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Activation, Dense 
from tensorflow.keras import Model
from keras import backend as K
import tensorflow as tf
from tensorflow.keras.utils import get_custom_objects

# Photo directory paths
train_path = 'data/Farm_Dataset/train'
valid_path = 'data/Farm_Dataset/valid'
test_path = 'data/Farm_Dataset/test'

# MobileNet expect 224 by 224 images.
# Process train, valid, and test batches.
train_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(
    directory=train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(
    directory=valid_path, target_size=(224,224), batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(
    directory=test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 1000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 600 images belonging to 4 classes.

# %%
mobile = keras.applications.MobileNetV3Small()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
mobile.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling (Rescaling)          (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  Conv (Conv2D)                  (None, None, None,   432         ['rescaling[0][0]']
#                                 16)
#
#  Conv/BatchNorm (BatchNormaliza  (None, None, None,   64         ['Conv[0][0]']
#  tion)                          16)
#
#  tf.__operators__.add (TFOpLamb  (None, None, None,   0          ['Conv/BatchNorm[0][0]']
#  da)                            16)
#
#  re_lu (ReLU)                   (None, None, None,   0           ['tf.__operators__.add[0][0]']
#                                 16)
#
#  tf.math.multiply (TFOpLambda)  (None, None, None,   0           ['re_lu[0][0]']
#                                 16)
#
#  multiply (Multiply)            (None, None, None,   0           ['Conv/BatchNorm[0][0]',
#                                 16)                               'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, None, None,   0          ['multiply[0][0]']
#  eroPadding2D)                  16)
#
#  expanded_conv/depthwise (Depth  (None, None, None,   144        ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                    16)                              0]']
#
#  expanded_conv/depthwise/BatchN  (None, None, None,   64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       16)
#
#  re_lu_1 (ReLU)                 (None, None, None,   0           ['expanded_conv/depthwise/BatchNo
#                                 16)                              rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_1[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  mbda)                                                           nv_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 1, 1, 16)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 16)    0           ['re_lu_2[0][0]']
#  )
#
#  expanded_conv/squeeze_excite/M  (None, None, None,   0          ['re_lu_1[0][0]',
#  ul (Multiply)                  16)                               'tf.math.multiply_1[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, None, None,   256        ['expanded_conv/squeeze_excite/Mu
#                                 16)                              l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, None, None,   64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         16)
#
#  expanded_conv_1/expand (Conv2D  (None, None, None,   1152       ['expanded_conv/project/BatchNorm
#  )                              72)                              [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, None, None,   288        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        72)
#
#  re_lu_3 (ReLU)                 (None, None, None,   0           ['expanded_conv_1/expand/BatchNor
#                                 72)                              m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, None, None,   0          ['re_lu_3[0][0]']
#  (ZeroPadding2D)                72)
#
#  expanded_conv_1/depthwise (Dep  (None, None, None,   648        ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                  72)                              ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, None, None,   288        ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)     72)                              ']
#
#  re_lu_4 (ReLU)                 (None, None, None,   0           ['expanded_conv_1/depthwise/Batch
#                                 72)                              Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, None, None,   1728       ['re_lu_4[0][0]']
#  D)                             24)
#
#  expanded_conv_1/project/BatchN  (None, None, None,   96         ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/expand (Conv2D  (None, None, None,   2112       ['expanded_conv_1/project/BatchNo
#  )                              88)                              rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, None, None,   352        ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)        88)
#
#  re_lu_5 (ReLU)                 (None, None, None,   0           ['expanded_conv_2/expand/BatchNor
#                                 88)                              m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, None, None,   792        ['re_lu_5[0][0]']
#  thwiseConv2D)                  88)
#
#  expanded_conv_2/depthwise/Batc  (None, None, None,   352        ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)     88)                              ']
#
#  re_lu_6 (ReLU)                 (None, None, None,   0           ['expanded_conv_2/depthwise/Batch
#                                 88)                              Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, None, None,   2112       ['re_lu_6[0][0]']
#  D)                             24)
#
#  expanded_conv_2/project/BatchN  (None, None, None,   96         ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/Add (Add)      (None, None, None,   0           ['expanded_conv_1/project/BatchNo
#                                 24)                              rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, None, None,   2304       ['expanded_conv_2/Add[0][0]']
#  )                              96)
#
#  expanded_conv_3/expand/BatchNo  (None, None, None,   384        ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)        96)
#
#  tf.__operators__.add_2 (TFOpLa  (None, None, None,   0          ['expanded_conv_3/expand/BatchNor
#  mbda)                          96)                              m[0][0]']
#
#  re_lu_7 (ReLU)                 (None, None, None,   0           ['tf.__operators__.add_2[0][0]']
#                                 96)
#
#  tf.math.multiply_2 (TFOpLambda  (None, None, None,   0          ['re_lu_7[0][0]']
#  )                              96)
#
#  multiply_1 (Multiply)          (None, None, None,   0           ['expanded_conv_3/expand/BatchNor
#                                 96)                              m[0][0]',
#                                                                   'tf.math.multiply_2[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, None, None,   0          ['multiply_1[0][0]']
#  (ZeroPadding2D)                96)
#
#  expanded_conv_3/depthwise (Dep  (None, None, None,   2400       ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                  96)                              ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, None, None,   384        ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)     96)                              ']
#
#  tf.__operators__.add_3 (TFOpLa  (None, None, None,   0          ['expanded_conv_3/depthwise/Batch
#  mbda)                          96)                              Norm[0][0]']
#
#  re_lu_8 (ReLU)                 (None, None, None,   0           ['tf.__operators__.add_3[0][0]']
#                                 96)
#
#  tf.math.multiply_3 (TFOpLambda  (None, None, None,   0          ['re_lu_8[0][0]']
#  )                              96)
#
#  multiply_2 (Multiply)          (None, None, None,   0           ['expanded_conv_3/depthwise/Batch
#                                 96)                              Norm[0][0]',
#                                                                   'tf.math.multiply_3[0][0]']
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_2[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 1, 1, 96)     0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1, 1, 96)    0           ['re_lu_9[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, None, None,   0          ['multiply_2[0][0]',
#  /Mul (Multiply)                96)                               'tf.math.multiply_4[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, None, None,   3840       ['expanded_conv_3/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, None, None,   160        ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_3/project/BatchNo
#  )                              240)                             rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, None, None,   960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_5 (TFOpLa  (None, None, None,   0          ['expanded_conv_4/expand/BatchNor
#  mbda)                          240)                             m[0][0]']
#
#  re_lu_10 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_5[0][0]']
#                                 240)
#
#  tf.math.multiply_5 (TFOpLambda  (None, None, None,   0          ['re_lu_10[0][0]']
#  )                              240)
#
#  multiply_3 (Multiply)          (None, None, None,   0           ['expanded_conv_4/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, None, None,   6000       ['multiply_3[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_4/depthwise/Batc  (None, None, None,   960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_6 (TFOpLa  (None, None, None,   0          ['expanded_conv_4/depthwise/Batch
#  mbda)                          240)                             Norm[0][0]']
#
#  re_lu_11 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_6[0][0]']
#                                 240)
#
#  tf.math.multiply_6 (TFOpLambda  (None, None, None,   0          ['re_lu_11[0][0]']
#  )                              240)
#
#  multiply_4 (Multiply)          (None, None, None,   0           ['expanded_conv_4/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_4[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_12 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 1, 1, 240)   0           ['re_lu_12[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, None, None,   0          ['multiply_4[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_7[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, None, None,   9600       ['expanded_conv_4/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, None, None,   160        ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/Add (Add)      (None, None, None,   0           ['expanded_conv_3/project/BatchNo
#                                 40)                              rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_4/Add[0][0]']
#  )                              240)
#
#  expanded_conv_5/expand/BatchNo  (None, None, None,   960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_8 (TFOpLa  (None, None, None,   0          ['expanded_conv_5/expand/BatchNor
#  mbda)                          240)                             m[0][0]']
#
#  re_lu_13 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_8[0][0]']
#                                 240)
#
#  tf.math.multiply_8 (TFOpLambda  (None, None, None,   0          ['re_lu_13[0][0]']
#  )                              240)
#
#  multiply_5 (Multiply)          (None, None, None,   0           ['expanded_conv_5/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, None, None,   6000       ['multiply_5[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_5/depthwise/Batc  (None, None, None,   960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, None, None,   0          ['expanded_conv_5/depthwise/Batch
#  mbda)                          240)                             Norm[0][0]']
#
#  re_lu_14 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_9[0][0]']
#                                 240)
#
#  tf.math.multiply_9 (TFOpLambda  (None, None, None,   0          ['re_lu_14[0][0]']
#  )                              240)
#
#  multiply_6 (Multiply)          (None, None, None,   0           ['expanded_conv_5/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_6[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_15 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_15[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, None, None,   0          ['multiply_6[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_10[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, None, None,   9600       ['expanded_conv_5/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, None, None,   160        ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_5/Add (Add)      (None, None, None,   0           ['expanded_conv_4/Add[0][0]',
#                                 40)                               'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, None, None,   4800       ['expanded_conv_5/Add[0][0]']
#  )                              120)
#
#  expanded_conv_6/expand/BatchNo  (None, None, None,   480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)        120)
#
#  tf.__operators__.add_11 (TFOpL  (None, None, None,   0          ['expanded_conv_6/expand/BatchNor
#  ambda)                         120)                             m[0][0]']
#
#  re_lu_16 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_11[0][0]']
#                                 120)
#
#  tf.math.multiply_11 (TFOpLambd  (None, None, None,   0          ['re_lu_16[0][0]']
#  a)                             120)
#
#  multiply_7 (Multiply)          (None, None, None,   0           ['expanded_conv_6/expand/BatchNor
#                                 120)                             m[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, None, None,   3000       ['multiply_7[0][0]']
#  thwiseConv2D)                  120)
#
#  expanded_conv_6/depthwise/Batc  (None, None, None,   480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)     120)                             ']
#
#  tf.__operators__.add_12 (TFOpL  (None, None, None,   0          ['expanded_conv_6/depthwise/Batch
#  ambda)                         120)                             Norm[0][0]']
#
#  re_lu_17 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_12[0][0]']
#                                 120)
#
#  tf.math.multiply_12 (TFOpLambd  (None, None, None,   0          ['re_lu_17[0][0]']
#  a)                             120)
#
#  multiply_8 (Multiply)          (None, None, None,   0           ['expanded_conv_6/depthwise/Batch
#                                 120)                             Norm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_8[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_18 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_18[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, None, None,   0          ['multiply_8[0][0]',
#  /Mul (Multiply)                120)                              'tf.math.multiply_13[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, None, None,   5760       ['expanded_conv_6/squeeze_excite/
#  D)                             48)                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, None, None,   192        ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)       48)
#
#  expanded_conv_7/expand (Conv2D  (None, None, None,   6912       ['expanded_conv_6/project/BatchNo
#  )                              144)                             rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, None, None,   576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)        144)
#  tf.__operators__.add_14 (TFOpL  (None, None, None,   0          ['expanded_conv_7/expand/BatchNor
#  ambda)                         144)                             m[0][0]']
#
#  re_lu_19 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_14[0][0]']
#                                 144)
#
#  tf.math.multiply_14 (TFOpLambd  (None, None, None,   0          ['re_lu_19[0][0]']
#  a)                             144)
#
#  multiply_9 (Multiply)          (None, None, None,   0           ['expanded_conv_7/expand/BatchNor
#                                 144)                             m[0][0]',
#                                                                   'tf.math.multiply_14[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, None, None,   3600       ['multiply_9[0][0]']
#  thwiseConv2D)                  144)
#
#  expanded_conv_7/depthwise/Batc  (None, None, None,   576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)     144)                             ']
#
#  tf.__operators__.add_15 (TFOpL  (None, None, None,   0          ['expanded_conv_7/depthwise/Batch
#  ambda)                         144)                             Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_15[0][0]']
#                                 144)
#
#  tf.math.multiply_15 (TFOpLambd  (None, None, None,   0          ['re_lu_20[0][0]']
#  a)                             144)
#
#  multiply_10 (Multiply)         (None, None, None,   0           ['expanded_conv_7/depthwise/Batch
#                                 144)                             Norm[0][0]',
#                                                                   'tf.math.multiply_15[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_21 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_16[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_21[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, None, None,   0          ['multiply_10[0][0]',
#  /Mul (Multiply)                144)                              'tf.math.multiply_16[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, None, None,   6912       ['expanded_conv_7/squeeze_excite/
#  D)                             48)                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, None, None,   192        ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)       48)
#
#  expanded_conv_7/Add (Add)      (None, None, None,   0           ['expanded_conv_6/project/BatchNo
#                                 48)                              rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, None, None,   13824      ['expanded_conv_7/Add[0][0]']
#  )                              288)
#
#  expanded_conv_8/expand/BatchNo  (None, None, None,   1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)        288)
# ...
#                                 576)
#
#  tf.math.multiply_21 (TFOpLambd  (None, None, None,   0          ['re_lu_26[0][0]']
#  a)                             576)
#
#  multiply_14 (Multiply)         (None, None, None,   0           ['expanded_conv_9/depthwise/Batch
#                                 576)                             Norm[0][0]',
#                                                                   'tf.math.multiply_21[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_14[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_27 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_27[0][0]']
#  a)
#
#  expanded_conv_9/squeeze_excite  (None, None, None,   0          ['multiply_14[0][0]',
#  /Mul (Multiply)                576)                              'tf.math.multiply_22[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, None, None,   55296      ['expanded_conv_9/squeeze_excite/
#  D)                             96)                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, None, None,   384        ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)       96)
#
#  expanded_conv_9/Add (Add)      (None, None, None,   0           ['expanded_conv_8/project/BatchNo
#                                 96)                              rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, None, None,   55296      ['expanded_conv_9/Add[0][0]']
#  D)                             576)
#
#  expanded_conv_10/expand/BatchN  (None, None, None,   2304       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)       576)
#
#  tf.__operators__.add_23 (TFOpL  (None, None, None,   0          ['expanded_conv_10/expand/BatchNo
#  ambda)                         576)                             rm[0][0]']
#
#  re_lu_28 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_23[0][0]']
#                                 576)
#
#  tf.math.multiply_23 (TFOpLambd  (None, None, None,   0          ['re_lu_28[0][0]']
#  a)                             576)
#
#  multiply_15 (Multiply)         (None, None, None,   0           ['expanded_conv_10/expand/BatchNo
#                                 576)                             rm[0][0]',
#                                                                   'tf.math.multiply_23[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, None, None,   14400      ['multiply_15[0][0]']
#  pthwiseConv2D)                 576)
#
#  expanded_conv_10/depthwise/Bat  (None, None, None,   2304       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)    576)                             ]']
#
#  tf.__operators__.add_24 (TFOpL  (None, None, None,   0          ['expanded_conv_10/depthwise/Batc
#  ambda)                         576)                             hNorm[0][0]']
#
#  re_lu_29 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_24[0][0]']
#                                 576)
#
#  tf.math.multiply_24 (TFOpLambd  (None, None, None,   0          ['re_lu_29[0][0]']
#  a)                             576)
#
#  multiply_16 (Multiply)         (None, None, None,   0           ['expanded_conv_10/depthwise/Batc
#                                 576)                             hNorm[0][0]',
#                                                                   'tf.math.multiply_24[0][0]']
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_16[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_30 (ReLU)                (None, 1, 1, 576)    0           ['tf.__operators__.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 1, 1, 576)   0           ['re_lu_30[0][0]']
#  a)
#
#  expanded_conv_10/squeeze_excit  (None, None, None,   0          ['multiply_16[0][0]',
#  e/Mul (Multiply)               576)                              'tf.math.multiply_25[0][0]']
#
#  expanded_conv_10/project (Conv  (None, None, None,   55296      ['expanded_conv_10/squeeze_excite
#  2D)                            96)                              /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, None, None,   384        ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)      96)                              ]
#
#  expanded_conv_10/Add (Add)     (None, None, None,   0           ['expanded_conv_9/Add[0][0]',
#                                 96)                               'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, None, None,   55296       ['expanded_conv_10/Add[0][0]']
#                                 576)
#
#  Conv_1/BatchNorm (BatchNormali  (None, None, None,   2304       ['Conv_1[0][0]']
#  zation)                        576)
#
#  tf.__operators__.add_26 (TFOpL  (None, None, None,   0          ['Conv_1/BatchNorm[0][0]']
#  ambda)                         576)
#
#  re_lu_31 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_26[0][0]']
#                                 576)
#
#  tf.math.multiply_26 (TFOpLambd  (None, None, None,   0          ['re_lu_31[0][0]']
#  a)                             576)
#
#  multiply_17 (Multiply)         (None, None, None,   0           ['Conv_1/BatchNorm[0][0]',
#                                 576)                              'tf.math.multiply_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1, 1, 576)   0           ['multiply_17[0][0]']
#  alAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1024)   590848      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  tf.__operators__.add_27 (TFOpL  (None, 1, 1, 1024)  0           ['Conv_2[0][0]']
#  ambda)
#
#  re_lu_32 (ReLU)                (None, 1, 1, 1024)   0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 1, 1, 1024)  0           ['re_lu_32[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 1, 1, 1024)   0           ['Conv_2[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
#  dropout (Dropout)              (None, 1, 1, 1024)   0           ['multiply_18[0][0]']
#
#  Logits (Conv2D)                (None, 1, 1, 1000)   1025000     ['dropout[0][0]']
#
#  flatten (Flatten)              (None, 1000)         0           ['Logits[0][0]']
#
#  Predictions (Activation)       (None, 1000)         0           ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 2,554,968
# Trainable params: 2,542,856
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
# Find selected layer as output layer
for layer in mobile.layers:
    if layer.name == 'expanded_conv_8/project/BatchNorm':
        output = layer.output
        print("Success!")
        break

# Reconstruct layers
model_1 = Model(inputs=mobile.inputs, outputs=output)
model_1.summary()
# Out:
# Success!
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling (Rescaling)          (None, None, None,   0           ['input_1[0][0]']
#                                 3)
#
#  Conv (Conv2D)                  (None, None, None,   432         ['rescaling[0][0]']
#                                 16)
#
#  Conv/BatchNorm (BatchNormaliza  (None, None, None,   64         ['Conv[0][0]']
#  tion)                          16)
#
#  tf.__operators__.add (TFOpLamb  (None, None, None,   0          ['Conv/BatchNorm[0][0]']
#  da)                            16)
#
#  re_lu (ReLU)                   (None, None, None,   0           ['tf.__operators__.add[0][0]']
#                                 16)
#
#  tf.math.multiply (TFOpLambda)  (None, None, None,   0           ['re_lu[0][0]']
#                                 16)
#
#  multiply (Multiply)            (None, None, None,   0           ['Conv/BatchNorm[0][0]',
#                                 16)                               'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, None, None,   0          ['multiply[0][0]']
#  eroPadding2D)                  16)
#
#  expanded_conv/depthwise (Depth  (None, None, None,   144        ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                    16)                              0]']
#
#  expanded_conv/depthwise/BatchN  (None, None, None,   64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       16)
#
#  re_lu_1 (ReLU)                 (None, None, None,   0           ['expanded_conv/depthwise/BatchNo
#                                 16)                              rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_1[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  mbda)                                                           nv_1[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 1, 1, 16)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 16)    0           ['re_lu_2[0][0]']
#  )
#
#  expanded_conv/squeeze_excite/M  (None, None, None,   0          ['re_lu_1[0][0]',
#  ul (Multiply)                  16)                               'tf.math.multiply_1[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, None, None,   256        ['expanded_conv/squeeze_excite/Mu
#                                 16)                              l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, None, None,   64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         16)
#
#  expanded_conv_1/expand (Conv2D  (None, None, None,   1152       ['expanded_conv/project/BatchNorm
#  )                              72)                              [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, None, None,   288        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        72)
#
#  re_lu_3 (ReLU)                 (None, None, None,   0           ['expanded_conv_1/expand/BatchNor
#                                 72)                              m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, None, None,   0          ['re_lu_3[0][0]']
#  (ZeroPadding2D)                72)
#
#  expanded_conv_1/depthwise (Dep  (None, None, None,   648        ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                  72)                              ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, None, None,   288        ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)     72)                              ']
#
#  re_lu_4 (ReLU)                 (None, None, None,   0           ['expanded_conv_1/depthwise/Batch
#                                 72)                              Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, None, None,   1728       ['re_lu_4[0][0]']
#  D)                             24)
#
#  expanded_conv_1/project/BatchN  (None, None, None,   96         ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/expand (Conv2D  (None, None, None,   2112       ['expanded_conv_1/project/BatchNo
#  )                              88)                              rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, None, None,   352        ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)        88)
#
#  re_lu_5 (ReLU)                 (None, None, None,   0           ['expanded_conv_2/expand/BatchNor
#                                 88)                              m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, None, None,   792        ['re_lu_5[0][0]']
#  thwiseConv2D)                  88)
#
#  expanded_conv_2/depthwise/Batc  (None, None, None,   352        ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)     88)                              ']
#
#  re_lu_6 (ReLU)                 (None, None, None,   0           ['expanded_conv_2/depthwise/Batch
#                                 88)                              Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, None, None,   2112       ['re_lu_6[0][0]']
#  D)                             24)
#
#  expanded_conv_2/project/BatchN  (None, None, None,   96         ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/Add (Add)      (None, None, None,   0           ['expanded_conv_1/project/BatchNo
#                                 24)                              rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, None, None,   2304       ['expanded_conv_2/Add[0][0]']
#  )                              96)
#
#  expanded_conv_3/expand/BatchNo  (None, None, None,   384        ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)        96)
#
#  tf.__operators__.add_2 (TFOpLa  (None, None, None,   0          ['expanded_conv_3/expand/BatchNor
#  mbda)                          96)                              m[0][0]']
#
#  re_lu_7 (ReLU)                 (None, None, None,   0           ['tf.__operators__.add_2[0][0]']
#                                 96)
#
#  tf.math.multiply_2 (TFOpLambda  (None, None, None,   0          ['re_lu_7[0][0]']
#  )                              96)
#
#  multiply_1 (Multiply)          (None, None, None,   0           ['expanded_conv_3/expand/BatchNor
#                                 96)                              m[0][0]',
#                                                                   'tf.math.multiply_2[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, None, None,   0          ['multiply_1[0][0]']
#  (ZeroPadding2D)                96)
#
#  expanded_conv_3/depthwise (Dep  (None, None, None,   2400       ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                  96)                              ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, None, None,   384        ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)     96)                              ']
#
#  tf.__operators__.add_3 (TFOpLa  (None, None, None,   0          ['expanded_conv_3/depthwise/Batch
#  mbda)                          96)                              Norm[0][0]']
#
#  re_lu_8 (ReLU)                 (None, None, None,   0           ['tf.__operators__.add_3[0][0]']
#                                 96)
#
#  tf.math.multiply_3 (TFOpLambda  (None, None, None,   0          ['re_lu_8[0][0]']
#  )                              96)
#
#  multiply_2 (Multiply)          (None, None, None,   0           ['expanded_conv_3/depthwise/Batch
#                                 96)                              Norm[0][0]',
#                                                                   'tf.math.multiply_3[0][0]']
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_2[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 1, 1, 96)     0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1, 1, 96)    0           ['re_lu_9[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, None, None,   0          ['multiply_2[0][0]',
#  /Mul (Multiply)                96)                               'tf.math.multiply_4[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, None, None,   3840       ['expanded_conv_3/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, None, None,   160        ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_3/project/BatchNo
#  )                              240)                             rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, None, None,   960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_5 (TFOpLa  (None, None, None,   0          ['expanded_conv_4/expand/BatchNor
#  mbda)                          240)                             m[0][0]']
#
#  re_lu_10 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_5[0][0]']
#                                 240)
#
#  tf.math.multiply_5 (TFOpLambda  (None, None, None,   0          ['re_lu_10[0][0]']
#  )                              240)
#
#  multiply_3 (Multiply)          (None, None, None,   0           ['expanded_conv_4/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, None, None,   6000       ['multiply_3[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_4/depthwise/Batc  (None, None, None,   960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_6 (TFOpLa  (None, None, None,   0          ['expanded_conv_4/depthwise/Batch
#  mbda)                          240)                             Norm[0][0]']
#
#  re_lu_11 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_6[0][0]']
#                                 240)
#
#  tf.math.multiply_6 (TFOpLambda  (None, None, None,   0          ['re_lu_11[0][0]']
#  )                              240)
#
#  multiply_4 (Multiply)          (None, None, None,   0           ['expanded_conv_4/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_4[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_12 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 1, 1, 240)   0           ['re_lu_12[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, None, None,   0          ['multiply_4[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_7[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, None, None,   9600       ['expanded_conv_4/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, None, None,   160        ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/Add (Add)      (None, None, None,   0           ['expanded_conv_3/project/BatchNo
#                                 40)                              rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_4/Add[0][0]']
#  )                              240)
#
#  expanded_conv_5/expand/BatchNo  (None, None, None,   960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_8 (TFOpLa  (None, None, None,   0          ['expanded_conv_5/expand/BatchNor
#  mbda)                          240)                             m[0][0]']
#
#  re_lu_13 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_8[0][0]']
#                                 240)
#
#  tf.math.multiply_8 (TFOpLambda  (None, None, None,   0          ['re_lu_13[0][0]']
#  )                              240)
#
#  multiply_5 (Multiply)          (None, None, None,   0           ['expanded_conv_5/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, None, None,   6000       ['multiply_5[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_5/depthwise/Batc  (None, None, None,   960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, None, None,   0          ['expanded_conv_5/depthwise/Batch
#  mbda)                          240)                             Norm[0][0]']
#
#  re_lu_14 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_9[0][0]']
#                                 240)
#
#  tf.math.multiply_9 (TFOpLambda  (None, None, None,   0          ['re_lu_14[0][0]']
#  )                              240)
#
#  multiply_6 (Multiply)          (None, None, None,   0           ['expanded_conv_5/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_6[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_15 (ReLU)                (None, 1, 1, 240)    0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_15[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, None, None,   0          ['multiply_6[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_10[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, None, None,   9600       ['expanded_conv_5/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, None, None,   160        ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_5/Add (Add)      (None, None, None,   0           ['expanded_conv_4/Add[0][0]',
#                                 40)                               'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, None, None,   4800       ['expanded_conv_5/Add[0][0]']
#  )                              120)
#
#  expanded_conv_6/expand/BatchNo  (None, None, None,   480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)        120)
#
#  tf.__operators__.add_11 (TFOpL  (None, None, None,   0          ['expanded_conv_6/expand/BatchNor
#  ambda)                         120)                             m[0][0]']
#
#  re_lu_16 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_11[0][0]']
#                                 120)
#
#  tf.math.multiply_11 (TFOpLambd  (None, None, None,   0          ['re_lu_16[0][0]']
#  a)                             120)
#
#  multiply_7 (Multiply)          (None, None, None,   0           ['expanded_conv_6/expand/BatchNor
#                                 120)                             m[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, None, None,   3000       ['multiply_7[0][0]']
#  thwiseConv2D)                  120)
#
#  expanded_conv_6/depthwise/Batc  (None, None, None,   480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)     120)                             ']
#
#  tf.__operators__.add_12 (TFOpL  (None, None, None,   0          ['expanded_conv_6/depthwise/Batch
#  ambda)                         120)                             Norm[0][0]']
#
#  re_lu_17 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_12[0][0]']
#                                 120)
#
#  tf.math.multiply_12 (TFOpLambd  (None, None, None,   0          ['re_lu_17[0][0]']
#  a)                             120)
#
#  multiply_8 (Multiply)          (None, None, None,   0           ['expanded_conv_6/depthwise/Batch
#                                 120)                             Norm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_8[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_18 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 1, 1, 120)   0           ['re_lu_18[0][0]']
#  a)
#
#  expanded_conv_6/squeeze_excite  (None, None, None,   0          ['multiply_8[0][0]',
#  /Mul (Multiply)                120)                              'tf.math.multiply_13[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, None, None,   5760       ['expanded_conv_6/squeeze_excite/
#  D)                             48)                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, None, None,   192        ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)       48)
#
#  expanded_conv_7/expand (Conv2D  (None, None, None,   6912       ['expanded_conv_6/project/BatchNo
#  )                              144)                             rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, None, None,   576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)        144)
#  tf.__operators__.add_14 (TFOpL  (None, None, None,   0          ['expanded_conv_7/expand/BatchNor
#  ambda)                         144)                             m[0][0]']
#
#  re_lu_19 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_14[0][0]']
#                                 144)
#
#  tf.math.multiply_14 (TFOpLambd  (None, None, None,   0          ['re_lu_19[0][0]']
#  a)                             144)
#
#  multiply_9 (Multiply)          (None, None, None,   0           ['expanded_conv_7/expand/BatchNor
#                                 144)                             m[0][0]',
#                                                                   'tf.math.multiply_14[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, None, None,   3600       ['multiply_9[0][0]']
#  thwiseConv2D)                  144)
#
#  expanded_conv_7/depthwise/Batc  (None, None, None,   576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)     144)                             ']
#
#  tf.__operators__.add_15 (TFOpL  (None, None, None,   0          ['expanded_conv_7/depthwise/Batch
#  ambda)                         144)                             Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_15[0][0]']
#                                 144)
#
#  tf.math.multiply_15 (TFOpLambd  (None, None, None,   0          ['re_lu_20[0][0]']
#  a)                             144)
#
#  multiply_10 (Multiply)         (None, None, None,   0           ['expanded_conv_7/depthwise/Batch
#                                 144)                             Norm[0][0]',
#                                                                   'tf.math.multiply_15[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_21 (ReLU)                (None, 1, 1, 144)    0           ['tf.__operators__.add_16[0][0]']
#
#  tf.math.multiply_16 (TFOpLambd  (None, 1, 1, 144)   0           ['re_lu_21[0][0]']
#  a)
#
#  expanded_conv_7/squeeze_excite  (None, None, None,   0          ['multiply_10[0][0]',
#  /Mul (Multiply)                144)                              'tf.math.multiply_16[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, None, None,   6912       ['expanded_conv_7/squeeze_excite/
#  D)                             48)                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, None, None,   192        ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)       48)
#
#  expanded_conv_7/Add (Add)      (None, None, None,   0           ['expanded_conv_6/project/BatchNo
#                                 48)                              rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, None, None,   13824      ['expanded_conv_7/Add[0][0]']
#  )                              288)
#
#  expanded_conv_8/expand/BatchNo  (None, None, None,   1152       ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)        288)
#
#  tf.__operators__.add_17 (TFOpL  (None, None, None,   0          ['expanded_conv_8/expand/BatchNor
#  ambda)                         288)                             m[0][0]']
#
#  re_lu_22 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_17[0][0]']
#                                 288)
#
#  tf.math.multiply_17 (TFOpLambd  (None, None, None,   0          ['re_lu_22[0][0]']
#  a)                             288)
#
#  multiply_11 (Multiply)         (None, None, None,   0           ['expanded_conv_8/expand/BatchNor
#                                 288)                             m[0][0]',
#                                                                   'tf.math.multiply_17[0][0]']
#
#  expanded_conv_8/depthwise/pad   (None, None, None,   0          ['multiply_11[0][0]']
#  (ZeroPadding2D)                288)
#
#  expanded_conv_8/depthwise (Dep  (None, None, None,   7200       ['expanded_conv_8/depthwise/pad[0
#  thwiseConv2D)                  288)                             ][0]']
#
#  expanded_conv_8/depthwise/Batc  (None, None, None,   1152       ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)     288)                             ']
#
#  tf.__operators__.add_18 (TFOpL  (None, None, None,   0          ['expanded_conv_8/depthwise/Batch
#  ambda)                         288)                             Norm[0][0]']
#
#  re_lu_23 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_18[0][0]']
#                                 288)
#
#  tf.math.multiply_18 (TFOpLambd  (None, None, None,   0          ['re_lu_23[0][0]']
#  a)                             288)
#
#  multiply_12 (Multiply)         (None, None, None,   0           ['expanded_conv_8/depthwise/Batch
#                                 288)                             Norm[0][0]',
#                                                                   'tf.math.multiply_18[0][0]']
#
#  expanded_conv_8/squeeze_excite  (None, 1, 1, 288)   0           ['multiply_12[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_8/squeeze_excite  (None, 1, 1, 72)    20808       ['expanded_conv_8/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_8/squeeze_excite  (None, 1, 1, 72)    0           ['expanded_conv_8/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_8/squeeze_excite  (None, 1, 1, 288)   21024       ['expanded_conv_8/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_19 (TFOpL  (None, 1, 1, 288)   0           ['expanded_conv_8/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_24 (ReLU)                (None, 1, 1, 288)    0           ['tf.__operators__.add_19[0][0]']
#
#  tf.math.multiply_19 (TFOpLambd  (None, 1, 1, 288)   0           ['re_lu_24[0][0]']
#  a)
#
#  expanded_conv_8/squeeze_excite  (None, None, None,   0          ['multiply_12[0][0]',
#  /Mul (Multiply)                288)                              'tf.math.multiply_19[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, None, None,   27648      ['expanded_conv_8/squeeze_excite/
#  D)                             96)                              Mul[0][0]']
#
#  expanded_conv_8/project/BatchN  (None, None, None,   384        ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)       96)
#
# ==================================================================================================
# Total params: 288,336
# Trainable params: 282,368
# Non-trainable params: 5,968
# __________________________________________________________________________________________________

# %%
# Find selected layer as input layer
for layer in mobile.layers:
    if layer.name == 'Conv_1':
        input_2 = layer.input
        print("Success!")
        break

# Reconstruct layers
x = mobile.layers[-2].output
output_2 = Dense(units=classes_number, activation='softmax')(x)
model_2 = Model(inputs=input_2, outputs=output_2)
model_2.summary()
# Out:
# Success!
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  96)]
#
#  Conv_1 (Conv2D)                (None, None, None,   55296       ['input_2[0][0]']
#                                 576)
#
#  Conv_1/BatchNorm (BatchNormali  (None, None, None,   2304       ['Conv_1[1][0]']
#  zation)                        576)
#
#  tf.__operators__.add_26 (TFOpL  (None, None, None,   0          ['Conv_1/BatchNorm[1][0]']
#  ambda)                         576)
#
#  re_lu_31 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_26[1][0]']
#                                 576)
#
#  tf.math.multiply_26 (TFOpLambd  (None, None, None,   0          ['re_lu_31[1][0]']
#  a)                             576)
#
#  multiply_17 (Multiply)         (None, None, None,   0           ['Conv_1/BatchNorm[1][0]',
#                                 576)                              'tf.math.multiply_26[1][0]']
#
#  global_average_pooling2d (Glob  (None, 1, 1, 576)   0           ['multiply_17[1][0]']
#  alAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1024)   590848      ['global_average_pooling2d[1][0]'
#                                                                  ]
#
#  tf.__operators__.add_27 (TFOpL  (None, 1, 1, 1024)  0           ['Conv_2[1][0]']
#  ambda)
#
#  re_lu_32 (ReLU)                (None, 1, 1, 1024)   0           ['tf.__operators__.add_27[1][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 1, 1, 1024)  0           ['re_lu_32[1][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 1, 1, 1024)   0           ['Conv_2[1][0]',
#                                                                   'tf.math.multiply_27[1][0]']
#
#  dropout (Dropout)              (None, 1, 1, 1024)   0           ['multiply_18[1][0]']
#
#  Logits (Conv2D)                (None, 1, 1, 1000)   1025000     ['dropout[1][0]']
#
#  flatten (Flatten)              (None, 1000)         0           ['Logits[1][0]']
#
#  dense (Dense)                  (None, 4)            4004        ['flatten[1][0]']
#
# ==================================================================================================
# Total params: 1,677,452
# Trainable params: 1,676,300
# Non-trainable params: 1,152
# __________________________________________________________________________________________________

# %%
# Combine all layers
combined_input = model_1.layers[0].input
x = model_1(combined_input)
output_2 = model_2(x)


model = Model(inputs=mobile.input, outputs=output_2)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  model (Functional)          (None, None, None, 96)    288336
#
#  model_1 (Functional)        (None, 4)                 1677452
#
# =================================================================
# Total params: 1,965,788
# Trainable params: 1,958,668
# Non-trainable params: 7,120
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import keras.losses

# Restore best weights from the 50th early weights
prediction = EarlyStopping(
    monitor="val_accuracy", patience=50, restore_best_weights=True
)

# Training model
history = model.fit(
    x=train_batches, 
    validation_data=valid_batches, 
    epochs=500, 
    verbose=2,
    callbacks=[prediction]
)
# Out:
# Epoch 1/500
# 100/100 - 62s - loss: 0.3621 - accuracy: 0.8500 - val_loss: 1.9015 - val_accuracy: 0.2500 - 62s/epoch - 617ms/step
# Epoch 2/500
# 100/100 - 69s - loss: 0.0619 - accuracy: 0.9840 - val_loss: 1.8699 - val_accuracy: 0.2500 - 69s/epoch - 689ms/step
# Epoch 3/500
# 100/100 - 33s - loss: 0.0312 - accuracy: 0.9910 - val_loss: 1.6782 - val_accuracy: 0.2500 - 33s/epoch - 328ms/step
# Epoch 4/500
# 100/100 - 31s - loss: 0.0192 - accuracy: 0.9940 - val_loss: 1.7369 - val_accuracy: 0.2500 - 31s/epoch - 308ms/step
# Epoch 5/500
# 100/100 - 32s - loss: 0.0117 - accuracy: 0.9970 - val_loss: 1.7583 - val_accuracy: 0.2500 - 32s/epoch - 319ms/step
# Epoch 6/500
# 100/100 - 40s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.8151 - val_accuracy: 0.2500 - 40s/epoch - 405ms/step
# Epoch 7/500
# 100/100 - 32s - loss: 0.0124 - accuracy: 0.9970 - val_loss: 1.8926 - val_accuracy: 0.2500 - 32s/epoch - 318ms/step
# Epoch 8/500
# 100/100 - 38s - loss: 0.0330 - accuracy: 0.9900 - val_loss: 1.8376 - val_accuracy: 0.2738 - 38s/epoch - 380ms/step
# Epoch 9/500
# 100/100 - 32s - loss: 0.0043 - accuracy: 0.9980 - val_loss: 1.8120 - val_accuracy: 0.3800 - 32s/epoch - 320ms/step
# Epoch 10/500
# 100/100 - 44s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.8846 - val_accuracy: 0.2500 - 44s/epoch - 443ms/step
# Epoch 11/500
# 100/100 - 28s - loss: 0.0092 - accuracy: 0.9960 - val_loss: 1.7083 - val_accuracy: 0.2537 - 28s/epoch - 284ms/step
# Epoch 12/500
# 100/100 - 30s - loss: 0.0015 - accuracy: 0.9990 - val_loss: 1.6113 - val_accuracy: 0.3275 - 30s/epoch - 304ms/step
# Epoch 13/500
# 100/100 - 24s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.7856 - val_accuracy: 0.2600 - 24s/epoch - 236ms/step
# Epoch 14/500
# 100/100 - 37s - loss: 0.0081 - accuracy: 0.9990 - val_loss: 1.8647 - val_accuracy: 0.2738 - 37s/epoch - 366ms/step
# Epoch 15/500
# 100/100 - 29s - loss: 0.0056 - accuracy: 0.9980 - val_loss: 1.6278 - val_accuracy: 0.2875 - 29s/epoch - 287ms/step
# Epoch 16/500
# 100/100 - 33s - loss: 0.0581 - accuracy: 0.9820 - val_loss: 1.4130 - val_accuracy: 0.2937 - 33s/epoch - 328ms/step
# Epoch 17/500
# 100/100 - 28s - loss: 0.0255 - accuracy: 0.9900 - val_loss: 1.5845 - val_accuracy: 0.2212 - 28s/epoch - 276ms/step
# Epoch 18/500
# 100/100 - 37s - loss: 0.0115 - accuracy: 0.9980 - val_loss: 2.9713 - val_accuracy: 0.2500 - 37s/epoch - 372ms/step
# Epoch 19/500
# 100/100 - 21s - loss: 0.0089 - accuracy: 0.9970 - val_loss: 4.6360 - val_accuracy: 0.2500 - 21s/epoch - 213ms/step
# Epoch 20/500
# 100/100 - 33s - loss: 0.0115 - accuracy: 0.9970 - val_loss: 3.4076 - val_accuracy: 0.2350 - 33s/epoch - 327ms/step
# Epoch 21/500
# 100/100 - 25s - loss: 0.0022 - accuracy: 0.9990 - val_loss: 4.2092 - val_accuracy: 0.2488 - 25s/epoch - 252ms/step
# Epoch 22/500
# 100/100 - 31s - loss: 0.0071 - accuracy: 0.9960 - val_loss: 4.1862 - val_accuracy: 0.2512 - 31s/epoch - 305ms/step
# Epoch 23/500
# 100/100 - 27s - loss: 0.0070 - accuracy: 0.9970 - val_loss: 4.8904 - val_accuracy: 0.2512 - 27s/epoch - 272ms/step
# Epoch 24/500
# 100/100 - 28s - loss: 0.0022 - accuracy: 0.9990 - val_loss: 2.3030 - val_accuracy: 0.3725 - 28s/epoch - 283ms/step
# Epoch 25/500
# 100/100 - 32s - loss: 5.5215e-04 - accuracy: 1.0000 - val_loss: 2.1477 - val_accuracy: 0.4850 - 32s/epoch - 317ms/step
# Epoch 26/500
# 100/100 - 34s - loss: 3.4617e-04 - accuracy: 1.0000 - val_loss: 2.2976 - val_accuracy: 0.5075 - 34s/epoch - 344ms/step
# Epoch 27/500
# 100/100 - 28s - loss: 0.0061 - accuracy: 0.9980 - val_loss: 3.2665 - val_accuracy: 0.3887 - 28s/epoch - 284ms/step
# Epoch 28/500
# 100/100 - 31s - loss: 0.0058 - accuracy: 0.9990 - val_loss: 1.7645 - val_accuracy: 0.5900 - 31s/epoch - 309ms/step
# Epoch 29/500
# 100/100 - 38s - loss: 0.0201 - accuracy: 0.9920 - val_loss: 3.0248 - val_accuracy: 0.4313 - 38s/epoch - 384ms/step
# Epoch 30/500
# 100/100 - 36s - loss: 0.0086 - accuracy: 0.9980 - val_loss: 2.8162 - val_accuracy: 0.4888 - 36s/epoch - 357ms/step
# Epoch 31/500
# 100/100 - 22s - loss: 2.7758e-04 - accuracy: 1.0000 - val_loss: 1.8209 - val_accuracy: 0.5512 - 22s/epoch - 217ms/step
# Epoch 32/500
# 100/100 - 35s - loss: 1.0496e-05 - accuracy: 1.0000 - val_loss: 1.6153 - val_accuracy: 0.5850 - 35s/epoch - 350ms/step
# Epoch 33/500
# 100/100 - 24s - loss: 0.0102 - accuracy: 0.9960 - val_loss: 2.8054 - val_accuracy: 0.5350 - 24s/epoch - 237ms/step
# Epoch 34/500
# 100/100 - 27s - loss: 0.0450 - accuracy: 0.9930 - val_loss: 3.9898 - val_accuracy: 0.3275 - 27s/epoch - 267ms/step
# Epoch 35/500
# 100/100 - 27s - loss: 0.0066 - accuracy: 0.9970 - val_loss: 3.4661 - val_accuracy: 0.4450 - 27s/epoch - 271ms/step
# Epoch 36/500
# 100/100 - 32s - loss: 0.0504 - accuracy: 0.9900 - val_loss: 6.7970 - val_accuracy: 0.4338 - 32s/epoch - 317ms/step
# Epoch 37/500
# 100/100 - 28s - loss: 0.0090 - accuracy: 0.9970 - val_loss: 4.2200 - val_accuracy: 0.4462 - 28s/epoch - 280ms/step
# Epoch 38/500
# 100/100 - 34s - loss: 0.0069 - accuracy: 0.9990 - val_loss: 5.7708 - val_accuracy: 0.4762 - 34s/epoch - 341ms/step
# Epoch 39/500
# 100/100 - 31s - loss: 0.0058 - accuracy: 0.9980 - val_loss: 3.6727 - val_accuracy: 0.4638 - 31s/epoch - 308ms/step
# Epoch 40/500
# 100/100 - 25s - loss: 0.0113 - accuracy: 0.9960 - val_loss: 1.1276 - val_accuracy: 0.6913 - 25s/epoch - 250ms/step
# Epoch 41/500
# 100/100 - 34s - loss: 0.0213 - accuracy: 0.9940 - val_loss: 1.4758 - val_accuracy: 0.6612 - 34s/epoch - 337ms/step
# Epoch 42/500
# 100/100 - 34s - loss: 0.0091 - accuracy: 0.9980 - val_loss: 3.0991 - val_accuracy: 0.6275 - 34s/epoch - 336ms/step
# Epoch 43/500
# 100/100 - 27s - loss: 1.0372e-04 - accuracy: 1.0000 - val_loss: 2.4443 - val_accuracy: 0.6350 - 27s/epoch - 273ms/step
# Epoch 44/500
# 100/100 - 42s - loss: 1.0306e-04 - accuracy: 1.0000 - val_loss: 2.0861 - val_accuracy: 0.6637 - 42s/epoch - 421ms/step
# Epoch 45/500
# 100/100 - 45s - loss: 3.3064e-04 - accuracy: 1.0000 - val_loss: 2.2535 - val_accuracy: 0.6825 - 45s/epoch - 448ms/step
# Epoch 46/500
# 100/100 - 29s - loss: 0.0105 - accuracy: 0.9970 - val_loss: 2.7931 - val_accuracy: 0.6075 - 29s/epoch - 293ms/step
# Epoch 47/500
# 100/100 - 21s - loss: 1.5710e-04 - accuracy: 1.0000 - val_loss: 1.0410 - val_accuracy: 0.8087 - 21s/epoch - 214ms/step
# Epoch 48/500
# 100/100 - 31s - loss: 6.6767e-05 - accuracy: 1.0000 - val_loss: 0.8145 - val_accuracy: 0.8487 - 31s/epoch - 312ms/step
# Epoch 49/500
# 100/100 - 29s - loss: 3.1646e-05 - accuracy: 1.0000 - val_loss: 0.6154 - val_accuracy: 0.8737 - 29s/epoch - 290ms/step
# Epoch 50/500
# 100/100 - 28s - loss: 3.0269e-05 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.9000 - 28s/epoch - 282ms/step
# Epoch 51/500
# 100/100 - 27s - loss: 0.0026 - accuracy: 0.9990 - val_loss: 1.4315 - val_accuracy: 0.7600 - 27s/epoch - 268ms/step
# Epoch 52/500
# 100/100 - 25s - loss: 4.1754e-04 - accuracy: 1.0000 - val_loss: 0.5771 - val_accuracy: 0.8725 - 25s/epoch - 251ms/step
# Epoch 53/500
# 100/100 - 25s - loss: 0.0066 - accuracy: 0.9990 - val_loss: 0.3001 - val_accuracy: 0.9362 - 25s/epoch - 252ms/step
# Epoch 54/500
# 100/100 - 31s - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.3155 - val_accuracy: 0.9362 - 31s/epoch - 310ms/step
# Epoch 55/500
# 100/100 - 27s - loss: 2.5612e-05 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 0.9538 - 27s/epoch - 266ms/step
# Epoch 56/500
# 100/100 - 32s - loss: 0.0875 - accuracy: 0.9880 - val_loss: 0.2304 - val_accuracy: 0.9388 - 32s/epoch - 317ms/step
# Epoch 57/500
# 100/100 - 24s - loss: 0.0923 - accuracy: 0.9860 - val_loss: 0.8087 - val_accuracy: 0.8988 - 24s/epoch - 242ms/step
# Epoch 58/500
# 100/100 - 29s - loss: 1.4781e-07 - accuracy: 1.0000 - val_loss: 0.7502 - val_accuracy: 0.9075 - 29s/epoch - 285ms/step
# Epoch 59/500
# 100/100 - 22s - loss: 3.4374e-05 - accuracy: 1.0000 - val_loss: 0.5720 - val_accuracy: 0.9162 - 22s/epoch - 217ms/step
# Epoch 60/500
# 100/100 - 27s - loss: 2.0383e-06 - accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.9237 - 27s/epoch - 273ms/step
# Epoch 61/500
# 100/100 - 25s - loss: 0.0096 - accuracy: 0.9950 - val_loss: 3.1331 - val_accuracy: 0.7350 - 25s/epoch - 252ms/step
# Epoch 62/500
# 100/100 - 28s - loss: 0.0272 - accuracy: 0.9960 - val_loss: 0.3194 - val_accuracy: 0.9438 - 28s/epoch - 285ms/step
# Epoch 63/500
# 100/100 - 26s - loss: 0.0330 - accuracy: 0.9940 - val_loss: 0.2388 - val_accuracy: 0.9663 - 26s/epoch - 255ms/step
# Epoch 64/500
# 100/100 - 41s - loss: 1.4838e-05 - accuracy: 1.0000 - val_loss: 0.1740 - val_accuracy: 0.9762 - 41s/epoch - 414ms/step
# Epoch 65/500
# 100/100 - 29s - loss: 1.6023e-05 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9825 - 29s/epoch - 290ms/step
# Epoch 66/500
# 100/100 - 29s - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0715 - val_accuracy: 0.9862 - 29s/epoch - 291ms/step
# Epoch 67/500
# 100/100 - 24s - loss: 0.0029 - accuracy: 0.9980 - val_loss: 0.1602 - val_accuracy: 0.9750 - 24s/epoch - 240ms/step
# Epoch 68/500
# 100/100 - 36s - loss: 0.0455 - accuracy: 0.9960 - val_loss: 0.8511 - val_accuracy: 0.9013 - 36s/epoch - 364ms/step
# Epoch 69/500
# 100/100 - 28s - loss: 3.7222e-06 - accuracy: 1.0000 - val_loss: 0.4870 - val_accuracy: 0.9400 - 28s/epoch - 284ms/step
# Epoch 70/500
# 100/100 - 32s - loss: 1.2737e-04 - accuracy: 1.0000 - val_loss: 0.2823 - val_accuracy: 0.9663 - 32s/epoch - 320ms/step
# Epoch 71/500
# 100/100 - 35s - loss: 2.5866e-04 - accuracy: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9762 - 35s/epoch - 347ms/step
# Epoch 72/500
# 100/100 - 37s - loss: 1.2971e-04 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9837 - 37s/epoch - 366ms/step
# Epoch 73/500
# 100/100 - 33s - loss: 2.8883e-04 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9862 - 33s/epoch - 331ms/step
# Epoch 74/500
# 100/100 - 35s - loss: 0.0807 - accuracy: 0.9900 - val_loss: 1.5309 - val_accuracy: 0.8388 - 35s/epoch - 351ms/step
# Epoch 75/500
# 100/100 - 22s - loss: 3.0516e-07 - accuracy: 1.0000 - val_loss: 0.6600 - val_accuracy: 0.9200 - 22s/epoch - 222ms/step
# Epoch 76/500
# 100/100 - 27s - loss: 0.0044 - accuracy: 0.9990 - val_loss: 0.8599 - val_accuracy: 0.8950 - 27s/epoch - 269ms/step
# Epoch 77/500
# 100/100 - 27s - loss: 0.0170 - accuracy: 0.9980 - val_loss: 2.8756 - val_accuracy: 0.7513 - 27s/epoch - 273ms/step
# Epoch 78/500
# 100/100 - 31s - loss: 0.0057 - accuracy: 0.9990 - val_loss: 0.0995 - val_accuracy: 0.9775 - 31s/epoch - 312ms/step
# Epoch 79/500
# 100/100 - 30s - loss: 2.1251e-05 - accuracy: 1.0000 - val_loss: 0.0358 - val_accuracy: 0.9900 - 30s/epoch - 305ms/step
# Epoch 80/500
# 100/100 - 38s - loss: 0.0217 - accuracy: 0.9960 - val_loss: 0.0302 - val_accuracy: 0.9900 - 38s/epoch - 383ms/step
# Epoch 81/500
# 100/100 - 25s - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0218 - val_accuracy: 0.9937 - 25s/epoch - 246ms/step
# Epoch 82/500
# 100/100 - 30s - loss: 1.1560e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.9975 - 30s/epoch - 305ms/step
# Epoch 83/500
# 100/100 - 34s - loss: 0.0012 - accuracy: 0.9990 - val_loss: 2.4645e-06 - val_accuracy: 1.0000 - 34s/epoch - 341ms/step
# Epoch 84/500
# 100/100 - 32s - loss: 2.1478e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9987 - 32s/epoch - 319ms/step
# Epoch 85/500
# 100/100 - 25s - loss: 2.8277e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 0.9987 - 25s/epoch - 252ms/step
# Epoch 86/500
# 100/100 - 34s - loss: 1.3234e-06 - accuracy: 1.0000 - val_loss: 6.1116e-04 - val_accuracy: 1.0000 - 34s/epoch - 340ms/step
# Epoch 87/500
# 100/100 - 26s - loss: 3.3744e-07 - accuracy: 1.0000 - val_loss: 2.3847e-04 - val_accuracy: 1.0000 - 26s/epoch - 265ms/step
# Epoch 88/500
# 100/100 - 29s - loss: 2.7101e-04 - accuracy: 1.0000 - val_loss: 5.2154e-09 - val_accuracy: 1.0000 - 29s/epoch - 287ms/step
# Epoch 89/500
# 100/100 - 30s - loss: 0.0020 - accuracy: 0.9990 - val_loss: 0.0186 - val_accuracy: 0.9962 - 30s/epoch - 304ms/step
# Epoch 90/500
# 100/100 - 29s - loss: 1.5497e-08 - accuracy: 1.0000 - val_loss: 9.2535e-06 - val_accuracy: 1.0000 - 29s/epoch - 292ms/step
# Epoch 91/500
# 100/100 - 23s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 3.2633e-08 - val_accuracy: 1.0000 - 23s/epoch - 229ms/step
# Epoch 92/500
# 100/100 - 29s - loss: 0.0012 - accuracy: 0.9990 - val_loss: 2.2742e-05 - val_accuracy: 1.0000 - 29s/epoch - 288ms/step
# Epoch 93/500
# 100/100 - 23s - loss: 0.0137 - accuracy: 0.9990 - val_loss: 0.0234 - val_accuracy: 0.9975 - 23s/epoch - 234ms/step
# Epoch 94/500
# 100/100 - 37s - loss: 0.0141 - accuracy: 0.9990 - val_loss: 9.4760e-04 - val_accuracy: 0.9987 - 37s/epoch - 373ms/step
# Epoch 95/500
# 100/100 - 25s - loss: 4.7616e-05 - accuracy: 1.0000 - val_loss: 5.3101e-05 - val_accuracy: 1.0000 - 25s/epoch - 250ms/step
# Epoch 96/500
# 100/100 - 39s - loss: 0.0152 - accuracy: 0.9980 - val_loss: 0.0159 - val_accuracy: 0.9975 - 39s/epoch - 387ms/step
# Epoch 97/500
# 100/100 - 24s - loss: 5.1211e-05 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9975 - 24s/epoch - 243ms/step
# Epoch 98/500
# 100/100 - 36s - loss: 2.4568e-07 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 0.9987 - 36s/epoch - 356ms/step
# Epoch 99/500
# 100/100 - 25s - loss: 5.9514e-04 - accuracy: 1.0000 - val_loss: 9.0211e-07 - val_accuracy: 1.0000 - 25s/epoch - 255ms/step
# Epoch 100/500
# 100/100 - 31s - loss: 3.4536e-04 - accuracy: 1.0000 - val_loss: 1.0204e-04 - val_accuracy: 1.0000 - 31s/epoch - 310ms/step
# Epoch 101/500
# 100/100 - 28s - loss: 5.5911e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - 28s/epoch - 279ms/step
# Epoch 102/500
# 100/100 - 36s - loss: 2.8487e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - 36s/epoch - 361ms/step
# Epoch 103/500
# 100/100 - 24s - loss: 6.7267e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 0.9987 - 24s/epoch - 242ms/step
# Epoch 104/500
# 100/100 - 30s - loss: 2.6299e-06 - accuracy: 1.0000 - val_loss: 2.2617e-04 - val_accuracy: 1.0000 - 30s/epoch - 303ms/step
# Epoch 105/500
# 100/100 - 19s - loss: 3.0756e-08 - accuracy: 1.0000 - val_loss: 4.1749e-05 - val_accuracy: 1.0000 - 19s/epoch - 188ms/step
# Epoch 106/500
# 100/100 - 33s - loss: 0.0090 - accuracy: 0.9990 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - 33s/epoch - 335ms/step
# Epoch 107/500
# 100/100 - 23s - loss: 0.0017 - accuracy: 0.9990 - val_loss: 0.1028 - val_accuracy: 0.9850 - 23s/epoch - 229ms/step
# Epoch 108/500
# 100/100 - 29s - loss: 0.1030 - accuracy: 0.9930 - val_loss: 0.0851 - val_accuracy: 0.9825 - 29s/epoch - 285ms/step
# Epoch 109/500
# 100/100 - 20s - loss: 0.0116 - accuracy: 0.9990 - val_loss: 0.0141 - val_accuracy: 0.9912 - 20s/epoch - 197ms/step
# Epoch 110/500
# 100/100 - 37s - loss: 6.9611e-04 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9937 - 37s/epoch - 367ms/step
# Epoch 111/500
# 100/100 - 30s - loss: 0.0056 - accuracy: 0.9990 - val_loss: 0.0682 - val_accuracy: 0.9912 - 30s/epoch - 297ms/step
# Epoch 112/500
# 100/100 - 34s - loss: 0.0219 - accuracy: 0.9980 - val_loss: 0.1225 - val_accuracy: 0.9700 - 34s/epoch - 339ms/step
# Epoch 113/500
# 100/100 - 24s - loss: 0.0345 - accuracy: 0.9950 - val_loss: 0.3140 - val_accuracy: 0.9563 - 24s/epoch - 238ms/step
# Epoch 114/500
# 100/100 - 21s - loss: 0.0067 - accuracy: 0.9990 - val_loss: 3.5053 - val_accuracy: 0.6250 - 21s/epoch - 215ms/step
# Epoch 115/500
# 100/100 - 32s - loss: 9.7519e-04 - accuracy: 1.0000 - val_loss: 3.6276 - val_accuracy: 0.6550 - 32s/epoch - 323ms/step
# Epoch 116/500
# 100/100 - 35s - loss: 2.9079e-05 - accuracy: 1.0000 - val_loss: 1.9920 - val_accuracy: 0.8012 - 35s/epoch - 355ms/step
# Epoch 117/500
# 100/100 - 18s - loss: 1.2460e-05 - accuracy: 1.0000 - val_loss: 1.0084 - val_accuracy: 0.9000 - 18s/epoch - 184ms/step
# Epoch 118/500
# 100/100 - 25s - loss: 1.5068e-07 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.9488 - 25s/epoch - 248ms/step
# Epoch 119/500
# 100/100 - 28s - loss: 6.7840e-05 - accuracy: 1.0000 - val_loss: 0.1692 - val_accuracy: 0.9775 - 28s/epoch - 285ms/step
# Epoch 120/500
# 100/100 - 32s - loss: 8.2967e-08 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9887 - 32s/epoch - 318ms/step
# Epoch 121/500
# 100/100 - 26s - loss: 7.2435e-04 - accuracy: 1.0000 - val_loss: 0.7982 - val_accuracy: 0.9225 - 26s/epoch - 258ms/step
# Epoch 122/500
# 100/100 - 43s - loss: 5.5670e-08 - accuracy: 1.0000 - val_loss: 0.3602 - val_accuracy: 0.9575 - 43s/epoch - 434ms/step
# Epoch 123/500
# 100/100 - 31s - loss: 9.4242e-06 - accuracy: 1.0000 - val_loss: 0.1457 - val_accuracy: 0.9825 - 31s/epoch - 314ms/step
# Epoch 124/500
# 100/100 - 33s - loss: 6.1836e-06 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9950 - 33s/epoch - 328ms/step
# Epoch 125/500
# 100/100 - 27s - loss: 0.0067 - accuracy: 0.9980 - val_loss: 1.7868e-05 - val_accuracy: 1.0000 - 27s/epoch - 274ms/step
# Epoch 126/500
# 100/100 - 38s - loss: 0.0034 - accuracy: 0.9980 - val_loss: 0.3164 - val_accuracy: 0.9688 - 38s/epoch - 377ms/step
# Epoch 127/500
# 100/100 - 30s - loss: 0.0024 - accuracy: 0.9990 - val_loss: 4.2170e-08 - val_accuracy: 1.0000 - 30s/epoch - 298ms/step
# Epoch 128/500
# 100/100 - 38s - loss: 0.0133 - accuracy: 0.9990 - val_loss: 0.0533 - val_accuracy: 0.9875 - 38s/epoch - 381ms/step
# Epoch 129/500
# 100/100 - 33s - loss: 0.0137 - accuracy: 0.9970 - val_loss: 4.7543 - val_accuracy: 0.7337 - 33s/epoch - 333ms/step
# Epoch 130/500
# 100/100 - 34s - loss: 0.0227 - accuracy: 0.9980 - val_loss: 8.9138 - val_accuracy: 0.5738 - 34s/epoch - 340ms/step
# Epoch 131/500
# 100/100 - 37s - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.9813 - val_accuracy: 0.9237 - 37s/epoch - 373ms/step
# Epoch 132/500
# 100/100 - 37s - loss: 0.0441 - accuracy: 0.9940 - val_loss: 7.6623 - val_accuracy: 0.4400 - 37s/epoch - 369ms/step
# Epoch 133/500
# 100/100 - 30s - loss: 6.6085e-05 - accuracy: 1.0000 - val_loss: 7.1019 - val_accuracy: 0.4625 - 30s/epoch - 303ms/step

# %%
def plot_all(history):
    """
    The plot_all() function takes the history of the trained model
    and create two plots for accuracy and loss of both training and validation.
    The plots are saved as png files

    Args:
        history: The history to use and plot

    """
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model_custom_Two_accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.savefig("plot_accuracy_mobile_custom_Two.png")
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model_custom_one_2loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.savefig("plot_loss_mobile_custom_Two.png")
    plt.show()
    

plot_all(history)
# Save model weights
model.save("Trained_Mobile_Custom_Two_Model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 44). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Trained_Mobile_Custom_Two_Model\assets
# INFO:tensorflow:Assets written to: Trained_Mobile_Custom_Two_Model\assets

# %%
# Create test batches
test_labels = test_batches.classes
predictions = model.predict(x=test_batches, verbose=0)

# %%
from sklearn.metrics import confusion_matrix

# Confusion matrix
cm = confusion_matrix(y_true=test_labels, y_pred=predictions.argmax(axis=1))

# %%
test_batches.class_indices
# Out:
# {'0': 0, '1': 1, '2': 2, '3': 3}

# %%
from matplotlib import pyplot as plt
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.savefig("confusion_mobile_custom_Two.png")
    

cm_plot_labels = ['Asparagus', 'BrusselSprouts', 'Celery', 'SliverBeet']
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[150   0   0   0]
#  [  0 150   0   0]
#  [  0   0 150   0]
#  [  0   0   0 150]]
