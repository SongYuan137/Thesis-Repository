# %%
import os
import shutil
import random
import keras
import tensorflow

classes_number = 4

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Activation, Dense 
from tensorflow.keras import Model
from keras import backend as K
import tensorflow as tf
from tensorflow.keras.utils import get_custom_objects

train_path = 'data/Farm_Dataset/train'
valid_path = 'data/Farm_Dataset/valid'
test_path = 'data/Farm_Dataset/test'

# MobileNet expect 224 by 224 images.
train_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(
    directory=train_path, target_size=(224,224), batch_size=10)
valid_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(
    directory=valid_path, target_size=(224,224), batch_size=10)
test_batches = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet.preprocess_input).flow_from_directory(
    directory=test_path, target_size=(224,224), batch_size=10, shuffle=False)
# Out:
# Found 1000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Found 600 images belonging to 4 classes.

# %%
mobile = keras.applications.MobileNetV3Small()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
mobile.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling_2 (Rescaling)        (None, None, None,   0           ['input_5[0][0]']
#                                 3)
#
#  Conv (Conv2D)                  (None, None, None,   432         ['rescaling_2[0][0]']
#                                 16)
#
#  Conv/BatchNorm (BatchNormaliza  (None, None, None,   64         ['Conv[0][0]']
#  tion)                          16)
#
#  tf.__operators__.add_89 (TFOpL  (None, None, None,   0          ['Conv/BatchNorm[0][0]']
#  ambda)                         16)
#
#  re_lu_99 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_89[0][0]']
#                                 16)
#
#  tf.math.multiply_89 (TFOpLambd  (None, None, None,   0          ['re_lu_99[0][0]']
#  a)                             16)
#
#  multiply_60 (Multiply)         (None, None, None,   0           ['Conv/BatchNorm[0][0]',
#                                 16)                               'tf.math.multiply_89[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, None, None,   0          ['multiply_60[0][0]']
#  eroPadding2D)                  16)
#
#  expanded_conv/depthwise (Depth  (None, None, None,   144        ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                    16)                              0]']
#
#  expanded_conv/depthwise/BatchN  (None, None, None,   64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       16)
#
#  re_lu_100 (ReLU)               (None, None, None,   0           ['expanded_conv/depthwise/BatchNo
#                                 16)                              rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_100[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_90 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_101 (ReLU)               (None, 1, 1, 16)     0           ['tf.__operators__.add_90[0][0]']
#
#  tf.math.multiply_90 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_101[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, None, None,   0          ['re_lu_100[0][0]',
#  ul (Multiply)                  16)                               'tf.math.multiply_90[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, None, None,   256        ['expanded_conv/squeeze_excite/Mu
#                                 16)                              l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, None, None,   64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         16)
#
#  expanded_conv_1/expand (Conv2D  (None, None, None,   1152       ['expanded_conv/project/BatchNorm
#  )                              72)                              [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, None, None,   288        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        72)
#
#  re_lu_102 (ReLU)               (None, None, None,   0           ['expanded_conv_1/expand/BatchNor
#                                 72)                              m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, None, None,   0          ['re_lu_102[0][0]']
#  (ZeroPadding2D)                72)
#
#  expanded_conv_1/depthwise (Dep  (None, None, None,   648        ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                  72)                              ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, None, None,   288        ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)     72)                              ']
#
#  re_lu_103 (ReLU)               (None, None, None,   0           ['expanded_conv_1/depthwise/Batch
#                                 72)                              Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, None, None,   1728       ['re_lu_103[0][0]']
#  D)                             24)
#
#  expanded_conv_1/project/BatchN  (None, None, None,   96         ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/expand (Conv2D  (None, None, None,   2112       ['expanded_conv_1/project/BatchNo
#  )                              88)                              rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, None, None,   352        ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)        88)
#
#  re_lu_104 (ReLU)               (None, None, None,   0           ['expanded_conv_2/expand/BatchNor
#                                 88)                              m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, None, None,   792        ['re_lu_104[0][0]']
#  thwiseConv2D)                  88)
#
#  expanded_conv_2/depthwise/Batc  (None, None, None,   352        ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)     88)                              ']
#
#  re_lu_105 (ReLU)               (None, None, None,   0           ['expanded_conv_2/depthwise/Batch
#                                 88)                              Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, None, None,   2112       ['re_lu_105[0][0]']
#  D)                             24)
#
#  expanded_conv_2/project/BatchN  (None, None, None,   96         ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/Add (Add)      (None, None, None,   0           ['expanded_conv_1/project/BatchNo
#                                 24)                              rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, None, None,   2304       ['expanded_conv_2/Add[0][0]']
#  )                              96)
#
#  expanded_conv_3/expand/BatchNo  (None, None, None,   384        ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)        96)
#
#  tf.__operators__.add_91 (TFOpL  (None, None, None,   0          ['expanded_conv_3/expand/BatchNor
#  ambda)                         96)                              m[0][0]']
#
#  re_lu_106 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_91[0][0]']
#                                 96)
#
#  tf.math.multiply_91 (TFOpLambd  (None, None, None,   0          ['re_lu_106[0][0]']
#  a)                             96)
#
#  multiply_61 (Multiply)         (None, None, None,   0           ['expanded_conv_3/expand/BatchNor
#                                 96)                              m[0][0]',
#                                                                   'tf.math.multiply_91[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, None, None,   0          ['multiply_61[0][0]']
#  (ZeroPadding2D)                96)
#
#  expanded_conv_3/depthwise (Dep  (None, None, None,   2400       ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                  96)                              ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, None, None,   384        ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)     96)                              ']
#
#  tf.__operators__.add_92 (TFOpL  (None, None, None,   0          ['expanded_conv_3/depthwise/Batch
#  ambda)                         96)                              Norm[0][0]']
#
#  re_lu_107 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_92[0][0]']
#                                 96)
#
#  tf.math.multiply_92 (TFOpLambd  (None, None, None,   0          ['re_lu_107[0][0]']
#  a)                             96)
#
#  multiply_62 (Multiply)         (None, None, None,   0           ['expanded_conv_3/depthwise/Batch
#                                 96)                              Norm[0][0]',
#                                                                   'tf.math.multiply_92[0][0]']
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_62[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_93 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_108 (ReLU)               (None, 1, 1, 96)     0           ['tf.__operators__.add_93[0][0]']
#
#  tf.math.multiply_93 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_108[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, None, None,   0          ['multiply_62[0][0]',
#  /Mul (Multiply)                96)                               'tf.math.multiply_93[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, None, None,   3840       ['expanded_conv_3/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, None, None,   160        ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_3/project/BatchNo
#  )                              240)                             rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, None, None,   960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_94 (TFOpL  (None, None, None,   0          ['expanded_conv_4/expand/BatchNor
#  ambda)                         240)                             m[0][0]']
#
#  re_lu_109 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_94[0][0]']
#                                 240)
#
#  tf.math.multiply_94 (TFOpLambd  (None, None, None,   0          ['re_lu_109[0][0]']
#  a)                             240)
#
#  multiply_63 (Multiply)         (None, None, None,   0           ['expanded_conv_4/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_94[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, None, None,   6000       ['multiply_63[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_4/depthwise/Batc  (None, None, None,   960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_95 (TFOpL  (None, None, None,   0          ['expanded_conv_4/depthwise/Batch
#  ambda)                         240)                             Norm[0][0]']
#
#  re_lu_110 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_95[0][0]']
#                                 240)
#
#  tf.math.multiply_95 (TFOpLambd  (None, None, None,   0          ['re_lu_110[0][0]']
#  a)                             240)
#
#  multiply_64 (Multiply)         (None, None, None,   0           ['expanded_conv_4/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_95[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_64[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_96 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_111 (ReLU)               (None, 1, 1, 240)    0           ['tf.__operators__.add_96[0][0]']
#
#  tf.math.multiply_96 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_111[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, None, None,   0          ['multiply_64[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_96[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, None, None,   9600       ['expanded_conv_4/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, None, None,   160        ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/Add (Add)      (None, None, None,   0           ['expanded_conv_3/project/BatchNo
#                                 40)                              rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_4/Add[0][0]']
#  )                              240)
#
#  expanded_conv_5/expand/BatchNo  (None, None, None,   960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_97 (TFOpL  (None, None, None,   0          ['expanded_conv_5/expand/BatchNor
#  ambda)                         240)                             m[0][0]']
#
#  re_lu_112 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_97[0][0]']
#                                 240)
#
#  tf.math.multiply_97 (TFOpLambd  (None, None, None,   0          ['re_lu_112[0][0]']
#  a)                             240)
#
#  multiply_65 (Multiply)         (None, None, None,   0           ['expanded_conv_5/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_97[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, None, None,   6000       ['multiply_65[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_5/depthwise/Batc  (None, None, None,   960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_98 (TFOpL  (None, None, None,   0          ['expanded_conv_5/depthwise/Batch
#  ambda)                         240)                             Norm[0][0]']
#
#  re_lu_113 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_98[0][0]']
#                                 240)
#
#  tf.math.multiply_98 (TFOpLambd  (None, None, None,   0          ['re_lu_113[0][0]']
#  a)                             240)
#
#  multiply_66 (Multiply)         (None, None, None,   0           ['expanded_conv_5/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_98[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_66[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_99 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_114 (ReLU)               (None, 1, 1, 240)    0           ['tf.__operators__.add_99[0][0]']
#
#  tf.math.multiply_99 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_114[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, None, None,   0          ['multiply_66[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_99[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, None, None,   9600       ['expanded_conv_5/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, None, None,   160        ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_5/Add (Add)      (None, None, None,   0           ['expanded_conv_4/Add[0][0]',
#                                 40)                               'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, None, None,   4800       ['expanded_conv_5/Add[0][0]']
#  )                              120)
#
#  expanded_conv_6/expand/BatchNo  (None, None, None,   480        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)        120)
#
#  tf.__operators__.add_100 (TFOp  (None, None, None,   0          ['expanded_conv_6/expand/BatchNor
#  Lambda)                        120)                             m[0][0]']
#
#  re_lu_115 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_100[0][0]'
#                                 120)                             ]
#
#  tf.math.multiply_100 (TFOpLamb  (None, None, None,   0          ['re_lu_115[0][0]']
#  da)                            120)
#
#  multiply_67 (Multiply)         (None, None, None,   0           ['expanded_conv_6/expand/BatchNor
#                                 120)                             m[0][0]',
#                                                                   'tf.math.multiply_100[0][0]']
#
#  expanded_conv_6/depthwise (Dep  (None, None, None,   3000       ['multiply_67[0][0]']
#  thwiseConv2D)                  120)
#
#  expanded_conv_6/depthwise/Batc  (None, None, None,   480        ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)     120)                             ']
#
#  tf.__operators__.add_101 (TFOp  (None, None, None,   0          ['expanded_conv_6/depthwise/Batch
#  Lambda)                        120)                             Norm[0][0]']
#
#  re_lu_116 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_101[0][0]'
#                                 120)                             ]
#
#  tf.math.multiply_101 (TFOpLamb  (None, None, None,   0          ['re_lu_116[0][0]']
#  da)                            120)
#
#  multiply_68 (Multiply)         (None, None, None,   0           ['expanded_conv_6/depthwise/Batch
#                                 120)                             Norm[0][0]',
#                                                                   'tf.math.multiply_101[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   0           ['multiply_68[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_6/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_6/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_6/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_6/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_102 (TFOp  (None, 1, 1, 120)   0           ['expanded_conv_6/squeeze_excite/
#  Lambda)                                                         Conv_1[0][0]']
#
#  re_lu_117 (ReLU)               (None, 1, 1, 120)    0           ['tf.__operators__.add_102[0][0]'
#                                                                  ]
#
#  tf.math.multiply_102 (TFOpLamb  (None, 1, 1, 120)   0           ['re_lu_117[0][0]']
#  da)
#
#  expanded_conv_6/squeeze_excite  (None, None, None,   0          ['multiply_68[0][0]',
#  /Mul (Multiply)                120)                              'tf.math.multiply_102[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, None, None,   5760       ['expanded_conv_6/squeeze_excite/
#  D)                             48)                              Mul[0][0]']
#
#  expanded_conv_6/project/BatchN  (None, None, None,   192        ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)       48)
#
#  expanded_conv_7/expand (Conv2D  (None, None, None,   6912       ['expanded_conv_6/project/BatchNo
#  )                              144)                             rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, None, None,   576        ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)        144)
#
#  tf.__operators__.add_103 (TFOp  (None, None, None,   0          ['expanded_conv_7/expand/BatchNor
#  Lambda)                        144)                             m[0][0]']
#
#  re_lu_118 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_103[0][0]'
#                                 144)                             ]
#
#  tf.math.multiply_103 (TFOpLamb  (None, None, None,   0          ['re_lu_118[0][0]']
#  da)                            144)
#
#  multiply_69 (Multiply)         (None, None, None,   0           ['expanded_conv_7/expand/BatchNor
#                                 144)                             m[0][0]',
#                                                                   'tf.math.multiply_103[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, None, None,   3600       ['multiply_69[0][0]']
#  thwiseConv2D)                  144)
#
#  expanded_conv_7/depthwise/Batc  (None, None, None,   576        ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)     144)                             ']
#
#  tf.__operators__.add_104 (TFOp  (None, None, None,   0          ['expanded_conv_7/depthwise/Batch
#  Lambda)                        144)                             Norm[0][0]']
#
#  re_lu_119 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_104[0][0]'
#                                 144)                             ]
#
#  tf.math.multiply_104 (TFOpLamb  (None, None, None,   0          ['re_lu_119[0][0]']
#  da)                            144)
#
#  multiply_70 (Multiply)         (None, None, None,   0           ['expanded_conv_7/depthwise/Batch
#                                 144)                             Norm[0][0]',
#                                                                   'tf.math.multiply_104[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   0           ['multiply_70[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    5800        ['expanded_conv_7/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 40)    0           ['expanded_conv_7/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_7/squeeze_excite  (None, 1, 1, 144)   5904        ['expanded_conv_7/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_105 (TFOp  (None, 1, 1, 144)   0           ['expanded_conv_7/squeeze_excite/
#  Lambda)                                                         Conv_1[0][0]']
#
#  re_lu_120 (ReLU)               (None, 1, 1, 144)    0           ['tf.__operators__.add_105[0][0]'
#                                                                  ]
#
#  tf.math.multiply_105 (TFOpLamb  (None, 1, 1, 144)   0           ['re_lu_120[0][0]']
#  da)
#
#  expanded_conv_7/squeeze_excite  (None, None, None,   0          ['multiply_70[0][0]',
#  /Mul (Multiply)                144)                              'tf.math.multiply_105[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, None, None,   6912       ['expanded_conv_7/squeeze_excite/
#  D)                             48)                              Mul[0][0]']
#
#  expanded_conv_7/project/BatchN  (None, None, None,   192        ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)       48)
#
#  expanded_conv_7/Add (Add)      (None, None, None,   0           ['expanded_conv_6/project/BatchNo
#                                 48)                              rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, None, None,   13824      ['expanded_conv_7/Add[0][0]']
#  )                              288)
# ...
#
#  tf.math.multiply_110 (TFOpLamb  (None, None, None,   0          ['re_lu_125[0][0]']
#  da)                            576)
#
#  multiply_74 (Multiply)         (None, None, None,   0           ['expanded_conv_9/depthwise/Batch
#                                 576)                             Norm[0][0]',
#                                                                   'tf.math.multiply_110[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_74[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_111 (TFOp  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  Lambda)                                                         Conv_1[0][0]']
#
#  re_lu_126 (ReLU)               (None, 1, 1, 576)    0           ['tf.__operators__.add_111[0][0]'
#                                                                  ]
#
#  tf.math.multiply_111 (TFOpLamb  (None, 1, 1, 576)   0           ['re_lu_126[0][0]']
#  da)
#
#  expanded_conv_9/squeeze_excite  (None, None, None,   0          ['multiply_74[0][0]',
#  /Mul (Multiply)                576)                              'tf.math.multiply_111[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, None, None,   55296      ['expanded_conv_9/squeeze_excite/
#  D)                             96)                              Mul[0][0]']
#
#  expanded_conv_9/project/BatchN  (None, None, None,   384        ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)       96)
#
#  expanded_conv_9/Add (Add)      (None, None, None,   0           ['expanded_conv_8/project/BatchNo
#                                 96)                              rm[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, None, None,   55296      ['expanded_conv_9/Add[0][0]']
#  D)                             576)
#
#  expanded_conv_10/expand/BatchN  (None, None, None,   2304       ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)       576)
#
#  tf.__operators__.add_112 (TFOp  (None, None, None,   0          ['expanded_conv_10/expand/BatchNo
#  Lambda)                        576)                             rm[0][0]']
#
#  re_lu_127 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_112[0][0]'
#                                 576)                             ]
#
#  tf.math.multiply_112 (TFOpLamb  (None, None, None,   0          ['re_lu_127[0][0]']
#  da)                            576)
#
#  multiply_75 (Multiply)         (None, None, None,   0           ['expanded_conv_10/expand/BatchNo
#                                 576)                             rm[0][0]',
#                                                                   'tf.math.multiply_112[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, None, None,   14400      ['multiply_75[0][0]']
#  pthwiseConv2D)                 576)
#
#  expanded_conv_10/depthwise/Bat  (None, None, None,   2304       ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)    576)                             ]']
#
#  tf.__operators__.add_113 (TFOp  (None, None, None,   0          ['expanded_conv_10/depthwise/Batc
#  Lambda)                        576)                             hNorm[0][0]']
#
#  re_lu_128 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_113[0][0]'
#                                 576)                             ]
#
#  tf.math.multiply_113 (TFOpLamb  (None, None, None,   0          ['re_lu_128[0][0]']
#  da)                            576)
#  multiply_76 (Multiply)         (None, None, None,   0           ['expanded_conv_10/depthwise/Batc
#                                 576)                             hNorm[0][0]',
#                                                                   'tf.math.multiply_113[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_76[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_114 (TFOp  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  Lambda)                                                         /Conv_1[0][0]']
#
#  re_lu_129 (ReLU)               (None, 1, 1, 576)    0           ['tf.__operators__.add_114[0][0]'
#                                                                  ]
#
#  tf.math.multiply_114 (TFOpLamb  (None, 1, 1, 576)   0           ['re_lu_129[0][0]']
#  da)
#
#  expanded_conv_10/squeeze_excit  (None, None, None,   0          ['multiply_76[0][0]',
#  e/Mul (Multiply)               576)                              'tf.math.multiply_114[0][0]']
#
#  expanded_conv_10/project (Conv  (None, None, None,   55296      ['expanded_conv_10/squeeze_excite
#  2D)                            96)                              /Mul[0][0]']
#
#  expanded_conv_10/project/Batch  (None, None, None,   384        ['expanded_conv_10/project[0][0]'
#  Norm (BatchNormalization)      96)                              ]
#
#  expanded_conv_10/Add (Add)     (None, None, None,   0           ['expanded_conv_9/Add[0][0]',
#                                 96)                               'expanded_conv_10/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, None, None,   55296       ['expanded_conv_10/Add[0][0]']
#                                 576)
#
#  Conv_1/BatchNorm (BatchNormali  (None, None, None,   2304       ['Conv_1[0][0]']
#  zation)                        576)
#
#  tf.__operators__.add_115 (TFOp  (None, None, None,   0          ['Conv_1/BatchNorm[0][0]']
#  Lambda)                        576)
#
#  re_lu_130 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_115[0][0]'
#                                 576)                             ]
#
#  tf.math.multiply_115 (TFOpLamb  (None, None, None,   0          ['re_lu_130[0][0]']
#  da)                            576)
#
#  multiply_77 (Multiply)         (None, None, None,   0           ['Conv_1/BatchNorm[0][0]',
#                                 576)                              'tf.math.multiply_115[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1, 1, 576)   0           ['multiply_77[0][0]']
#  obalAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1024)   590848      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  tf.__operators__.add_116 (TFOp  (None, 1, 1, 1024)  0           ['Conv_2[0][0]']
#  Lambda)
#
#  re_lu_131 (ReLU)               (None, 1, 1, 1024)   0           ['tf.__operators__.add_116[0][0]'
#                                                                  ]
#
#  tf.math.multiply_116 (TFOpLamb  (None, 1, 1, 1024)  0           ['re_lu_131[0][0]']
#  da)
#
#  multiply_78 (Multiply)         (None, 1, 1, 1024)   0           ['Conv_2[0][0]',
#                                                                   'tf.math.multiply_116[0][0]']
#
#  dropout_2 (Dropout)            (None, 1, 1, 1024)   0           ['multiply_78[0][0]']
#
#  Logits (Conv2D)                (None, 1, 1, 1000)   1025000     ['dropout_2[0][0]']
#
#  flatten_2 (Flatten)            (None, 1000)         0           ['Logits[0][0]']
#
#  Predictions (Activation)       (None, 1000)         0           ['flatten_2[0][0]']
# ==================================================================================================
# Total params: 2,554,968
# Trainable params: 2,542,856
# Non-trainable params: 12,112
# __________________________________________________________________________________________________

# %%
for layer in mobile.layers:
    if layer.name == 'expanded_conv_5/Add':
        output = layer.output
        print("Success!")
        break

model_1 = Model(inputs=mobile.inputs, outputs=output)
model_1.summary()
# Out:
# Success!
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  rescaling_2 (Rescaling)        (None, None, None,   0           ['input_5[0][0]']
#                                 3)
#
#  Conv (Conv2D)                  (None, None, None,   432         ['rescaling_2[0][0]']
#                                 16)
#
#  Conv/BatchNorm (BatchNormaliza  (None, None, None,   64         ['Conv[0][0]']
#  tion)                          16)
#
#  tf.__operators__.add_89 (TFOpL  (None, None, None,   0          ['Conv/BatchNorm[0][0]']
#  ambda)                         16)
#
#  re_lu_99 (ReLU)                (None, None, None,   0           ['tf.__operators__.add_89[0][0]']
#                                 16)
#
#  tf.math.multiply_89 (TFOpLambd  (None, None, None,   0          ['re_lu_99[0][0]']
#  a)                             16)
#
#  multiply_60 (Multiply)         (None, None, None,   0           ['Conv/BatchNorm[0][0]',
#                                 16)                               'tf.math.multiply_89[0][0]']
#
#  expanded_conv/depthwise/pad (Z  (None, None, None,   0          ['multiply_60[0][0]']
#  eroPadding2D)                  16)
#
#  expanded_conv/depthwise (Depth  (None, None, None,   144        ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                    16)                              0]']
#
#  expanded_conv/depthwise/BatchN  (None, None, None,   64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       16)
#
#  re_lu_100 (ReLU)               (None, None, None,   0           ['expanded_conv/depthwise/BatchNo
#                                 16)                              rm[0][0]']
#
#  expanded_conv/squeeze_excite/A  (None, 1, 1, 16)    0           ['re_lu_100[0][0]']
#  vgPool (GlobalAveragePooling2D
#  )
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 8)     136         ['expanded_conv/squeeze_excite/Av
#  onv (Conv2D)                                                    gPool[0][0]']
#
#  expanded_conv/squeeze_excite/R  (None, 1, 1, 8)     0           ['expanded_conv/squeeze_excite/Co
#  elu (ReLU)                                                      nv[0][0]']
#
#  expanded_conv/squeeze_excite/C  (None, 1, 1, 16)    144         ['expanded_conv/squeeze_excite/Re
#  onv_1 (Conv2D)                                                  lu[0][0]']
#
#  tf.__operators__.add_90 (TFOpL  (None, 1, 1, 16)    0           ['expanded_conv/squeeze_excite/Co
#  ambda)                                                          nv_1[0][0]']
#
#  re_lu_101 (ReLU)               (None, 1, 1, 16)     0           ['tf.__operators__.add_90[0][0]']
#
#  tf.math.multiply_90 (TFOpLambd  (None, 1, 1, 16)    0           ['re_lu_101[0][0]']
#  a)
#
#  expanded_conv/squeeze_excite/M  (None, None, None,   0          ['re_lu_100[0][0]',
#  ul (Multiply)                  16)                               'tf.math.multiply_90[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, None, None,   256        ['expanded_conv/squeeze_excite/Mu
#                                 16)                              l[0][0]']
#
#  expanded_conv/project/BatchNor  (None, None, None,   64         ['expanded_conv/project[0][0]']
#  m (BatchNormalization)         16)
#
#  expanded_conv_1/expand (Conv2D  (None, None, None,   1152       ['expanded_conv/project/BatchNorm
#  )                              72)                              [0][0]']
#
#  expanded_conv_1/expand/BatchNo  (None, None, None,   288        ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)        72)
#
#  re_lu_102 (ReLU)               (None, None, None,   0           ['expanded_conv_1/expand/BatchNor
#                                 72)                              m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, None, None,   0          ['re_lu_102[0][0]']
#  (ZeroPadding2D)                72)
#
#  expanded_conv_1/depthwise (Dep  (None, None, None,   648        ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                  72)                              ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, None, None,   288        ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)     72)                              ']
#
#  re_lu_103 (ReLU)               (None, None, None,   0           ['expanded_conv_1/depthwise/Batch
#                                 72)                              Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, None, None,   1728       ['re_lu_103[0][0]']
#  D)                             24)
#
#  expanded_conv_1/project/BatchN  (None, None, None,   96         ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/expand (Conv2D  (None, None, None,   2112       ['expanded_conv_1/project/BatchNo
#  )                              88)                              rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, None, None,   352        ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)        88)
#
#  re_lu_104 (ReLU)               (None, None, None,   0           ['expanded_conv_2/expand/BatchNor
#                                 88)                              m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, None, None,   792        ['re_lu_104[0][0]']
#  thwiseConv2D)                  88)
#
#  expanded_conv_2/depthwise/Batc  (None, None, None,   352        ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)     88)                              ']
#
#  re_lu_105 (ReLU)               (None, None, None,   0           ['expanded_conv_2/depthwise/Batch
#                                 88)                              Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, None, None,   2112       ['re_lu_105[0][0]']
#  D)                             24)
#
#  expanded_conv_2/project/BatchN  (None, None, None,   96         ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)       24)
#
#  expanded_conv_2/Add (Add)      (None, None, None,   0           ['expanded_conv_1/project/BatchNo
#                                 24)                              rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, None, None,   2304       ['expanded_conv_2/Add[0][0]']
#  )                              96)
#
#  expanded_conv_3/expand/BatchNo  (None, None, None,   384        ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)        96)
#
#  tf.__operators__.add_91 (TFOpL  (None, None, None,   0          ['expanded_conv_3/expand/BatchNor
#  ambda)                         96)                              m[0][0]']
#
#  re_lu_106 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_91[0][0]']
#                                 96)
#
#  tf.math.multiply_91 (TFOpLambd  (None, None, None,   0          ['re_lu_106[0][0]']
#  a)                             96)
#
#  multiply_61 (Multiply)         (None, None, None,   0           ['expanded_conv_3/expand/BatchNor
#                                 96)                              m[0][0]',
#                                                                   'tf.math.multiply_91[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, None, None,   0          ['multiply_61[0][0]']
#  (ZeroPadding2D)                96)
#
#  expanded_conv_3/depthwise (Dep  (None, None, None,   2400       ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                  96)                              ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, None, None,   384        ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)     96)                              ']
#
#  tf.__operators__.add_92 (TFOpL  (None, None, None,   0          ['expanded_conv_3/depthwise/Batch
#  ambda)                         96)                              Norm[0][0]']
#
#  re_lu_107 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_92[0][0]']
#                                 96)
#
#  tf.math.multiply_92 (TFOpLambd  (None, None, None,   0          ['re_lu_107[0][0]']
#  a)                             96)
#
#  multiply_62 (Multiply)         (None, None, None,   0           ['expanded_conv_3/depthwise/Batch
#                                 96)                              Norm[0][0]',
#                                                                   'tf.math.multiply_92[0][0]']
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    0           ['multiply_62[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    2328        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 96)    2400        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_93 (TFOpL  (None, 1, 1, 96)    0           ['expanded_conv_3/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_108 (ReLU)               (None, 1, 1, 96)     0           ['tf.__operators__.add_93[0][0]']
#
#  tf.math.multiply_93 (TFOpLambd  (None, 1, 1, 96)    0           ['re_lu_108[0][0]']
#  a)
#
#  expanded_conv_3/squeeze_excite  (None, None, None,   0          ['multiply_62[0][0]',
#  /Mul (Multiply)                96)                               'tf.math.multiply_93[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, None, None,   3840       ['expanded_conv_3/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, None, None,   160        ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_3/project/BatchNo
#  )                              240)                             rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, None, None,   960        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_94 (TFOpL  (None, None, None,   0          ['expanded_conv_4/expand/BatchNor
#  ambda)                         240)                             m[0][0]']
#
#  re_lu_109 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_94[0][0]']
#                                 240)
#
#  tf.math.multiply_94 (TFOpLambd  (None, None, None,   0          ['re_lu_109[0][0]']
#  a)                             240)
#
#  multiply_63 (Multiply)         (None, None, None,   0           ['expanded_conv_4/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_94[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, None, None,   6000       ['multiply_63[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_4/depthwise/Batc  (None, None, None,   960        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_95 (TFOpL  (None, None, None,   0          ['expanded_conv_4/depthwise/Batch
#  ambda)                         240)                             Norm[0][0]']
#
#  re_lu_110 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_95[0][0]']
#                                 240)
#
#  tf.math.multiply_95 (TFOpLambd  (None, None, None,   0          ['re_lu_110[0][0]']
#  a)                             240)
#
#  multiply_64 (Multiply)         (None, None, None,   0           ['expanded_conv_4/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_95[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_64[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_96 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_4/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_111 (ReLU)               (None, 1, 1, 240)    0           ['tf.__operators__.add_96[0][0]']
#
#  tf.math.multiply_96 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_111[0][0]']
#  a)
#
#  expanded_conv_4/squeeze_excite  (None, None, None,   0          ['multiply_64[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_96[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, None, None,   9600       ['expanded_conv_4/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, None, None,   160        ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_4/Add (Add)      (None, None, None,   0           ['expanded_conv_3/project/BatchNo
#                                 40)                              rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, None, None,   9600       ['expanded_conv_4/Add[0][0]']
#  )                              240)
#
#  expanded_conv_5/expand/BatchNo  (None, None, None,   960        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)        240)
#
#  tf.__operators__.add_97 (TFOpL  (None, None, None,   0          ['expanded_conv_5/expand/BatchNor
#  ambda)                         240)                             m[0][0]']
#
#  re_lu_112 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_97[0][0]']
#                                 240)
#
#  tf.math.multiply_97 (TFOpLambd  (None, None, None,   0          ['re_lu_112[0][0]']
#  a)                             240)
#
#  multiply_65 (Multiply)         (None, None, None,   0           ['expanded_conv_5/expand/BatchNor
#                                 240)                             m[0][0]',
#                                                                   'tf.math.multiply_97[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, None, None,   6000       ['multiply_65[0][0]']
#  thwiseConv2D)                  240)
#
#  expanded_conv_5/depthwise/Batc  (None, None, None,   960        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)     240)                             ']
#
#  tf.__operators__.add_98 (TFOpL  (None, None, None,   0          ['expanded_conv_5/depthwise/Batch
#  ambda)                         240)                             Norm[0][0]']
#
#  re_lu_113 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_98[0][0]']
#                                 240)
#
#  tf.math.multiply_98 (TFOpLambd  (None, None, None,   0          ['re_lu_113[0][0]']
#  a)                             240)
#
#  multiply_66 (Multiply)         (None, None, None,   0           ['expanded_conv_5/depthwise/Batch
#                                 240)                             Norm[0][0]',
#                                                                   'tf.math.multiply_98[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   0           ['multiply_66[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    15424       ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 64)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 240)   15600       ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_99 (TFOpL  (None, 1, 1, 240)   0           ['expanded_conv_5/squeeze_excite/
#  ambda)                                                          Conv_1[0][0]']
#
#  re_lu_114 (ReLU)               (None, 1, 1, 240)    0           ['tf.__operators__.add_99[0][0]']
#
#  tf.math.multiply_99 (TFOpLambd  (None, 1, 1, 240)   0           ['re_lu_114[0][0]']
#  a)
#
#  expanded_conv_5/squeeze_excite  (None, None, None,   0          ['multiply_66[0][0]',
#  /Mul (Multiply)                240)                              'tf.math.multiply_99[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, None, None,   9600       ['expanded_conv_5/squeeze_excite/
#  D)                             40)                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, None, None,   160        ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)       40)
#
#  expanded_conv_5/Add (Add)      (None, None, None,   0           ['expanded_conv_4/Add[0][0]',
#                                 40)                               'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
# ==================================================================================================
# Total params: 142,128
# Trainable params: 138,752
# Non-trainable params: 3,376
# __________________________________________________________________________________________________

# %%
for layer in mobile.layers:
    if layer.name == 'expanded_conv_9/expand':
        input_3 = layer.input
        print("Success!")
        break

        
x = mobile.layers[-2].output
output_3 = Dense(units=classes_number, activation='softmax')(x)

model_3 = Model(inputs=input_3, outputs=output_3)
model_3.summary()
# Out:
# Success!
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, None, None,  0           []
#                                  96)]
#
#  expanded_conv_9/expand (Conv2D  (None, None, None,   55296      ['input_6[0][0]']
#  )                              576)
#
#  expanded_conv_9/expand/BatchNo  (None, None, None,   2304       ['expanded_conv_9/expand[1][0]']
#  rm (BatchNormalization)        576)
#
#  tf.__operators__.add_109 (TFOp  (None, None, None,   0          ['expanded_conv_9/expand/BatchNor
#  Lambda)                        576)                             m[1][0]']
#
#  re_lu_124 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_109[1][0]'
#                                 576)                             ]
#
#  tf.math.multiply_109 (TFOpLamb  (None, None, None,   0          ['re_lu_124[1][0]']
#  da)                            576)
#
#  multiply_73 (Multiply)         (None, None, None,   0           ['expanded_conv_9/expand/BatchNor
#                                 576)                             m[1][0]',
#                                                                   'tf.math.multiply_109[1][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, None, None,   14400      ['multiply_73[1][0]']
#  thwiseConv2D)                  576)
#
#  expanded_conv_9/depthwise/Batc  (None, None, None,   2304       ['expanded_conv_9/depthwise[1][0]
#  hNorm (BatchNormalization)     576)                             ']
#
#  tf.__operators__.add_110 (TFOp  (None, None, None,   0          ['expanded_conv_9/depthwise/Batch
#  Lambda)                        576)                             Norm[1][0]']
#
#  re_lu_125 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_110[1][0]'
#                                 576)                             ]
#
#  tf.math.multiply_110 (TFOpLamb  (None, None, None,   0          ['re_lu_125[1][0]']
#  da)                            576)
#
#  multiply_74 (Multiply)         (None, None, None,   0           ['expanded_conv_9/depthwise/Batch
#                                 576)                             Norm[1][0]',
#                                                                   'tf.math.multiply_110[1][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   0           ['multiply_74[1][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   83088       ['expanded_conv_9/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[1][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 144)   0           ['expanded_conv_9/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[1][0]']
#
#  expanded_conv_9/squeeze_excite  (None, 1, 1, 576)   83520       ['expanded_conv_9/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[1][0]']
#
#  tf.__operators__.add_111 (TFOp  (None, 1, 1, 576)   0           ['expanded_conv_9/squeeze_excite/
#  Lambda)                                                         Conv_1[1][0]']
#
#  re_lu_126 (ReLU)               (None, 1, 1, 576)    0           ['tf.__operators__.add_111[1][0]'
#                                                                  ]
#
#  tf.math.multiply_111 (TFOpLamb  (None, 1, 1, 576)   0           ['re_lu_126[1][0]']
#  da)
#
#  expanded_conv_9/squeeze_excite  (None, None, None,   0          ['multiply_74[1][0]',
#  /Mul (Multiply)                576)                              'tf.math.multiply_111[1][0]']
#
#  expanded_conv_9/project (Conv2  (None, None, None,   55296      ['expanded_conv_9/squeeze_excite/
#  D)                             96)                              Mul[1][0]']
#
#  expanded_conv_9/project/BatchN  (None, None, None,   384        ['expanded_conv_9/project[1][0]']
#  orm (BatchNormalization)       96)
#
#  expanded_conv_9/Add (Add)      (None, None, None,   0           ['input_6[0][0]',
#                                 96)                               'expanded_conv_9/project/BatchNo
#                                                                  rm[1][0]']
#
#  expanded_conv_10/expand (Conv2  (None, None, None,   55296      ['expanded_conv_9/Add[1][0]']
#  D)                             576)
#
#  expanded_conv_10/expand/BatchN  (None, None, None,   2304       ['expanded_conv_10/expand[1][0]']
#  orm (BatchNormalization)       576)
#
#  tf.__operators__.add_112 (TFOp  (None, None, None,   0          ['expanded_conv_10/expand/BatchNo
#  Lambda)                        576)                             rm[1][0]']
#
#  re_lu_127 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_112[1][0]'
#                                 576)                             ]
#
#  tf.math.multiply_112 (TFOpLamb  (None, None, None,   0          ['re_lu_127[1][0]']
#  da)                            576)
#
#  multiply_75 (Multiply)         (None, None, None,   0           ['expanded_conv_10/expand/BatchNo
#                                 576)                             rm[1][0]',
#                                                                   'tf.math.multiply_112[1][0]']
#
#  expanded_conv_10/depthwise (De  (None, None, None,   14400      ['multiply_75[1][0]']
#  pthwiseConv2D)                 576)
#
#  expanded_conv_10/depthwise/Bat  (None, None, None,   2304       ['expanded_conv_10/depthwise[1][0
#  chNorm (BatchNormalization)    576)                             ]']
#
#  tf.__operators__.add_113 (TFOp  (None, None, None,   0          ['expanded_conv_10/depthwise/Batc
#  Lambda)                        576)                             hNorm[1][0]']
#
#  re_lu_128 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_113[1][0]'
#                                 576)                             ]
#
#  tf.math.multiply_113 (TFOpLamb  (None, None, None,   0          ['re_lu_128[1][0]']
#  da)                            576)
#
#  multiply_76 (Multiply)         (None, None, None,   0           ['expanded_conv_10/depthwise/Batc
#                                 576)                             hNorm[1][0]',
#                                                                   'tf.math.multiply_113[1][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   0           ['multiply_76[1][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   83088       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[1][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 144)   0           ['expanded_conv_10/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[1][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 576)   83520       ['expanded_conv_10/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[1][0]']
#
#  tf.__operators__.add_114 (TFOp  (None, 1, 1, 576)   0           ['expanded_conv_10/squeeze_excite
#  Lambda)                                                         /Conv_1[1][0]']
#
#  re_lu_129 (ReLU)               (None, 1, 1, 576)    0           ['tf.__operators__.add_114[1][0]'
#                                                                  ]
#
#  tf.math.multiply_114 (TFOpLamb  (None, 1, 1, 576)   0           ['re_lu_129[1][0]']
#  da)
#
#  expanded_conv_10/squeeze_excit  (None, None, None,   0          ['multiply_76[1][0]',
#  e/Mul (Multiply)               576)                              'tf.math.multiply_114[1][0]']
#
#  expanded_conv_10/project (Conv  (None, None, None,   55296      ['expanded_conv_10/squeeze_excite
#  2D)                            96)                              /Mul[1][0]']
#
#  expanded_conv_10/project/Batch  (None, None, None,   384        ['expanded_conv_10/project[1][0]'
#  Norm (BatchNormalization)      96)                              ]
#
#  expanded_conv_10/Add (Add)     (None, None, None,   0           ['expanded_conv_9/Add[1][0]',
#                                 96)                               'expanded_conv_10/project/BatchN
#                                                                  orm[1][0]']
#
#  Conv_1 (Conv2D)                (None, None, None,   55296       ['expanded_conv_10/Add[1][0]']
#                                 576)
#
#  Conv_1/BatchNorm (BatchNormali  (None, None, None,   2304       ['Conv_1[1][0]']
#  zation)                        576)
#
#  tf.__operators__.add_115 (TFOp  (None, None, None,   0          ['Conv_1/BatchNorm[1][0]']
#  Lambda)                        576)
#
#  re_lu_130 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_115[1][0]'
#                                 576)                             ]
#
#  tf.math.multiply_115 (TFOpLamb  (None, None, None,   0          ['re_lu_130[1][0]']
#  da)                            576)
#
#  multiply_77 (Multiply)         (None, None, None,   0           ['Conv_1/BatchNorm[1][0]',
#                                 576)                              'tf.math.multiply_115[1][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1, 1, 576)   0           ['multiply_77[1][0]']
#  obalAveragePooling2D)
#
#  Conv_2 (Conv2D)                (None, 1, 1, 1024)   590848      ['global_average_pooling2d_2[1][0
#                                                                  ]']
#
#  tf.__operators__.add_116 (TFOp  (None, 1, 1, 1024)  0           ['Conv_2[1][0]']
#  Lambda)
#
#  re_lu_131 (ReLU)               (None, 1, 1, 1024)   0           ['tf.__operators__.add_116[1][0]'
#                                                                  ]
#
#  tf.math.multiply_116 (TFOpLamb  (None, 1, 1, 1024)  0           ['re_lu_131[1][0]']
#  da)
#
#  multiply_78 (Multiply)         (None, 1, 1, 1024)   0           ['Conv_2[1][0]',
#                                                                   'tf.math.multiply_116[1][0]']
#
#  dropout_2 (Dropout)            (None, 1, 1, 1024)   0           ['multiply_78[1][0]']
#
#  Logits (Conv2D)                (None, 1, 1, 1000)   1025000     ['dropout_2[1][0]']
#
#  flatten_2 (Flatten)            (None, 1000)         0           ['Logits[1][0]']
#
#  dense_2 (Dense)                (None, 4)            4004        ['flatten_2[1][0]']
#
# ==================================================================================================
# Total params: 2,270,636
# Trainable params: 2,264,492
# Non-trainable params: 6,144
# __________________________________________________________________________________________________

# %%
from MobileNetCode import _inverted_res_block_dilation

se_ratio = 0.25
activation = hard_swish
kernel = 3
alpha = 1

def depth(d):
    return _depth(d * alpha)

combined_input = model_1.layers[0].input
x = model_1(combined_input)
x = _inverted_res_block(x, 6, depth(96), kernel, 1, se_ratio, activation, 22)
output_3 = model_3(x)

model = Model(inputs=mobile.input, outputs=output_3)
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  model_6 (Functional)           (None, None, None,   142128      ['input_5[0][0]']
#                                 40)
#
#  expanded_conv_22/expand (Conv2  (None, None, None,   9600       ['model_6[5][0]']
#  D)                             240)
#
#  expanded_conv_22/expand/BatchN  (None, None, None,   960        ['expanded_conv_22/expand[0][0]']
#  orm (BatchNormalization)       240)
#
#  tf.__operators__.add_159 (TFOp  (None, None, None,   0          ['expanded_conv_22/expand/BatchNo
#  Lambda)                        240)                             rm[0][0]']
#
#  re_lu_174 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_159[0][0]'
#                                 240)                             ]
#
#  tf.math.multiply_159 (TFOpLamb  (None, None, None,   0          ['re_lu_174[0][0]']
#  da)                            240)
#
#  multiply_107 (Multiply)        (None, None, None,   0           ['expanded_conv_22/expand/BatchNo
#                                 240)                             rm[0][0]',
#                                                                   'tf.math.multiply_159[0][0]']
#
#  expanded_conv_22/depthwise (De  (None, None, None,   2160       ['multiply_107[0][0]']
#  pthwiseConv2D)                 240)
#
#  expanded_conv_22/depthwise/Bat  (None, None, None,   960        ['expanded_conv_22/depthwise[0][0
#  chNorm (BatchNormalization)    240)                             ]']
#
#  tf.__operators__.add_160 (TFOp  (None, None, None,   0          ['expanded_conv_22/depthwise/Batc
#  Lambda)                        240)                             hNorm[0][0]']
#
#  re_lu_175 (ReLU)               (None, None, None,   0           ['tf.__operators__.add_160[0][0]'
#                                 240)                             ]
#
#  tf.math.multiply_160 (TFOpLamb  (None, None, None,   0          ['re_lu_175[0][0]']
#  da)                            240)
#
#  multiply_108 (Multiply)        (None, None, None,   0           ['expanded_conv_22/depthwise/Batc
#                                 240)                             hNorm[0][0]',
#                                                                   'tf.math.multiply_160[0][0]']
#
#  expanded_conv_22/squeeze_excit  (None, 1, 1, 240)   0           ['multiply_108[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_22/squeeze_excit  (None, 1, 1, 64)    15424       ['expanded_conv_22/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_22/squeeze_excit  (None, 1, 1, 64)    0           ['expanded_conv_22/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_22/squeeze_excit  (None, 1, 1, 240)   15600       ['expanded_conv_22/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_161 (TFOp  (None, 1, 1, 240)   0           ['expanded_conv_22/squeeze_excite
#  Lambda)                                                         /Conv_1[0][0]']
#
#  re_lu_176 (ReLU)               (None, 1, 1, 240)    0           ['tf.__operators__.add_161[0][0]'
#                                                                  ]
#
#  tf.math.multiply_161 (TFOpLamb  (None, 1, 1, 240)   0           ['re_lu_176[0][0]']
#  da)
#
#  expanded_conv_22/squeeze_excit  (None, None, None,   0          ['multiply_108[0][0]',
#  e/Mul (Multiply)               240)                              'tf.math.multiply_161[0][0]']
#
#  expanded_conv_22/project (Conv  (None, None, None,   23040      ['expanded_conv_22/squeeze_excite
#  2D)                            96)                              /Mul[0][0]']
#
#  expanded_conv_22/project/Batch  (None, None, None,   384        ['expanded_conv_22/project[0][0]'
#  Norm (BatchNormalization)      96)                              ]
#
#  model_7 (Functional)           (None, 4)            2270636     ['expanded_conv_22/project/BatchN
#                                                                  orm[0][0]']
#
# ==================================================================================================
# Total params: 2,480,892
# Trainable params: 2,470,220
# Non-trainable params: 10,672
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from tensorflow import keras
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import keras.losses

prediction = EarlyStopping(
    monitor="val_accuracy", patience=50, restore_best_weights=True
)
history = model.fit(
    x=train_batches, 
    validation_data=valid_batches, 
    epochs=500, 
    verbose=2,
    callbacks=[prediction]
)
# Out:
# Epoch 1/500
# 100/100 - 53s - loss: 0.5190 - accuracy: 0.7950 - val_loss: 1.8463 - val_accuracy: 0.2500 - 53s/epoch - 534ms/step
# Epoch 2/500
# 100/100 - 48s - loss: 0.1049 - accuracy: 0.9630 - val_loss: 2.1684 - val_accuracy: 0.2500 - 48s/epoch - 475ms/step
# Epoch 3/500
# 100/100 - 44s - loss: 0.0684 - accuracy: 0.9780 - val_loss: 2.6124 - val_accuracy: 0.2500 - 44s/epoch - 438ms/step
# Epoch 4/500
# 100/100 - 40s - loss: 0.0196 - accuracy: 0.9940 - val_loss: 2.5129 - val_accuracy: 0.2500 - 40s/epoch - 400ms/step
# Epoch 5/500
# 100/100 - 46s - loss: 0.0275 - accuracy: 0.9880 - val_loss: 2.8733 - val_accuracy: 0.2500 - 46s/epoch - 462ms/step
# Epoch 6/500
# 100/100 - 47s - loss: 0.0322 - accuracy: 0.9940 - val_loss: 2.5585 - val_accuracy: 0.2500 - 47s/epoch - 469ms/step
# Epoch 7/500
# 100/100 - 47s - loss: 0.0292 - accuracy: 0.9920 - val_loss: 2.7297 - val_accuracy: 0.2500 - 47s/epoch - 470ms/step
# Epoch 8/500
# 100/100 - 48s - loss: 0.0413 - accuracy: 0.9880 - val_loss: 4.1918 - val_accuracy: 0.2500 - 48s/epoch - 478ms/step
# Epoch 9/500
# 100/100 - 61s - loss: 0.0060 - accuracy: 0.9980 - val_loss: 4.3427 - val_accuracy: 0.2500 - 61s/epoch - 614ms/step
# Epoch 10/500
# 100/100 - 50s - loss: 0.0075 - accuracy: 0.9970 - val_loss: 4.3102 - val_accuracy: 0.2500 - 50s/epoch - 497ms/step
# Epoch 11/500
# 100/100 - 51s - loss: 0.0126 - accuracy: 0.9950 - val_loss: 4.1852 - val_accuracy: 0.2500 - 51s/epoch - 509ms/step
# Epoch 12/500
# 100/100 - 41s - loss: 0.0436 - accuracy: 0.9850 - val_loss: 3.3733 - val_accuracy: 0.2500 - 41s/epoch - 413ms/step
# Epoch 13/500
# 100/100 - 58s - loss: 0.0037 - accuracy: 0.9990 - val_loss: 3.4030 - val_accuracy: 0.2500 - 58s/epoch - 580ms/step
# Epoch 14/500
# 100/100 - 53s - loss: 9.2807e-04 - accuracy: 1.0000 - val_loss: 3.3838 - val_accuracy: 0.2500 - 53s/epoch - 535ms/step
# Epoch 15/500
# 100/100 - 43s - loss: 0.0170 - accuracy: 0.9930 - val_loss: 3.9898 - val_accuracy: 0.2500 - 43s/epoch - 429ms/step
# Epoch 16/500
# 100/100 - 43s - loss: 0.0041 - accuracy: 0.9980 - val_loss: 4.4390 - val_accuracy: 0.2500 - 43s/epoch - 434ms/step
# Epoch 17/500
# 100/100 - 47s - loss: 0.0188 - accuracy: 0.9950 - val_loss: 4.8507 - val_accuracy: 0.2500 - 47s/epoch - 472ms/step
# Epoch 18/500
# 100/100 - 46s - loss: 0.0036 - accuracy: 0.9990 - val_loss: 5.6635 - val_accuracy: 0.2500 - 46s/epoch - 457ms/step
# Epoch 19/500
# 100/100 - 42s - loss: 8.2730e-04 - accuracy: 1.0000 - val_loss: 5.6697 - val_accuracy: 0.2500 - 42s/epoch - 425ms/step
# Epoch 20/500
# 100/100 - 43s - loss: 0.0128 - accuracy: 0.9940 - val_loss: 4.3316 - val_accuracy: 0.2500 - 43s/epoch - 432ms/step
# Epoch 21/500
# 100/100 - 46s - loss: 0.0258 - accuracy: 0.9900 - val_loss: 4.1293 - val_accuracy: 0.2500 - 46s/epoch - 459ms/step
# Epoch 22/500
# 100/100 - 42s - loss: 0.1306 - accuracy: 0.9810 - val_loss: 4.6330 - val_accuracy: 0.2500 - 42s/epoch - 415ms/step
# Epoch 23/500
# 100/100 - 43s - loss: 0.0614 - accuracy: 0.9890 - val_loss: 3.1035 - val_accuracy: 0.2500 - 43s/epoch - 426ms/step
# Epoch 24/500
# 100/100 - 43s - loss: 0.0178 - accuracy: 0.9950 - val_loss: 3.7965 - val_accuracy: 0.2500 - 43s/epoch - 425ms/step
# Epoch 25/500
# 100/100 - 53s - loss: 0.0229 - accuracy: 0.9930 - val_loss: 3.9458 - val_accuracy: 0.2500 - 53s/epoch - 529ms/step
# Epoch 26/500
# 100/100 - 42s - loss: 0.0063 - accuracy: 0.9970 - val_loss: 4.2762 - val_accuracy: 0.2500 - 42s/epoch - 421ms/step
# Epoch 27/500
# 100/100 - 43s - loss: 0.0018 - accuracy: 0.9990 - val_loss: 3.9767 - val_accuracy: 0.2500 - 43s/epoch - 428ms/step
# Epoch 28/500
# 100/100 - 40s - loss: 0.0023 - accuracy: 0.9990 - val_loss: 5.2747 - val_accuracy: 0.2500 - 40s/epoch - 402ms/step
# Epoch 29/500
# 100/100 - 48s - loss: 5.1126e-04 - accuracy: 1.0000 - val_loss: 5.0806 - val_accuracy: 0.2500 - 48s/epoch - 482ms/step
# Epoch 30/500
# 100/100 - 43s - loss: 0.0164 - accuracy: 0.9950 - val_loss: 2.4105 - val_accuracy: 0.2950 - 43s/epoch - 432ms/step
# Epoch 31/500
# 100/100 - 47s - loss: 0.0128 - accuracy: 0.9950 - val_loss: 2.2492 - val_accuracy: 0.2500 - 47s/epoch - 465ms/step
# Epoch 32/500
# 100/100 - 46s - loss: 0.0030 - accuracy: 0.9980 - val_loss: 2.5128 - val_accuracy: 0.2500 - 46s/epoch - 463ms/step
# Epoch 33/500
# 100/100 - 43s - loss: 0.0107 - accuracy: 0.9960 - val_loss: 3.2881 - val_accuracy: 0.2500 - 43s/epoch - 427ms/step
# Epoch 34/500
# 100/100 - 50s - loss: 0.0345 - accuracy: 0.9940 - val_loss: 3.4242 - val_accuracy: 0.2500 - 50s/epoch - 500ms/step
# Epoch 35/500
# 100/100 - 46s - loss: 0.0191 - accuracy: 0.9960 - val_loss: 5.3450 - val_accuracy: 0.2500 - 46s/epoch - 461ms/step
# Epoch 36/500
# 100/100 - 50s - loss: 0.0069 - accuracy: 0.9990 - val_loss: 6.8394 - val_accuracy: 0.2500 - 50s/epoch - 495ms/step
# Epoch 37/500
# 100/100 - 61s - loss: 0.0026 - accuracy: 0.9990 - val_loss: 5.6310 - val_accuracy: 0.2500 - 61s/epoch - 612ms/step
# Epoch 38/500
# 100/100 - 43s - loss: 0.0027 - accuracy: 0.9980 - val_loss: 6.8696 - val_accuracy: 0.2500 - 43s/epoch - 426ms/step
# Epoch 39/500
# 100/100 - 44s - loss: 3.1868e-04 - accuracy: 1.0000 - val_loss: 8.4941 - val_accuracy: 0.2500 - 44s/epoch - 437ms/step
# Epoch 40/500
# 100/100 - 47s - loss: 5.1439e-05 - accuracy: 1.0000 - val_loss: 8.9172 - val_accuracy: 0.2500 - 47s/epoch - 474ms/step
# Epoch 41/500
# 100/100 - 52s - loss: 1.7701e-04 - accuracy: 1.0000 - val_loss: 9.2183 - val_accuracy: 0.2500 - 52s/epoch - 517ms/step
# Epoch 42/500
# 100/100 - 43s - loss: 0.0144 - accuracy: 0.9960 - val_loss: 7.4233 - val_accuracy: 0.2500 - 43s/epoch - 430ms/step
# Epoch 43/500
# 100/100 - 49s - loss: 0.0012 - accuracy: 0.9990 - val_loss: 7.2516 - val_accuracy: 0.2500 - 49s/epoch - 486ms/step
# Epoch 44/500
# 100/100 - 53s - loss: 2.5970e-04 - accuracy: 1.0000 - val_loss: 8.7237 - val_accuracy: 0.2500 - 53s/epoch - 530ms/step
# Epoch 45/500
# 100/100 - 47s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 7.9086 - val_accuracy: 0.2500 - 47s/epoch - 471ms/step
# Epoch 46/500
# 100/100 - 44s - loss: 0.0023 - accuracy: 0.9990 - val_loss: 11.3890 - val_accuracy: 0.2500 - 44s/epoch - 441ms/step
# Epoch 47/500
# 100/100 - 43s - loss: 0.0388 - accuracy: 0.9940 - val_loss: 18.9433 - val_accuracy: 0.2500 - 43s/epoch - 428ms/step
# Epoch 48/500
# 100/100 - 38s - loss: 0.0123 - accuracy: 0.9970 - val_loss: 18.5675 - val_accuracy: 0.2500 - 38s/epoch - 380ms/step
# Epoch 49/500
# 100/100 - 51s - loss: 0.0019 - accuracy: 0.9990 - val_loss: 18.6252 - val_accuracy: 0.2500 - 51s/epoch - 508ms/step
# Epoch 50/500
# 100/100 - 48s - loss: 0.0071 - accuracy: 0.9980 - val_loss: 17.3901 - val_accuracy: 0.2500 - 48s/epoch - 481ms/step
# Epoch 51/500
# 100/100 - 48s - loss: 0.0032 - accuracy: 0.9980 - val_loss: 17.2192 - val_accuracy: 0.2525 - 48s/epoch - 479ms/step
# Epoch 52/500
# 100/100 - 42s - loss: 0.0230 - accuracy: 0.9960 - val_loss: 7.2452 - val_accuracy: 0.2850 - 42s/epoch - 420ms/step
# Epoch 53/500
# 100/100 - 48s - loss: 0.0177 - accuracy: 0.9980 - val_loss: 8.4691 - val_accuracy: 0.2775 - 48s/epoch - 475ms/step
# Epoch 54/500
# 100/100 - 47s - loss: 0.0135 - accuracy: 0.9970 - val_loss: 14.9415 - val_accuracy: 0.2525 - 47s/epoch - 474ms/step
# Epoch 55/500
# 100/100 - 45s - loss: 0.0478 - accuracy: 0.9880 - val_loss: 13.1491 - val_accuracy: 0.3000 - 45s/epoch - 448ms/step
# Epoch 56/500
# 100/100 - 42s - loss: 0.0803 - accuracy: 0.9840 - val_loss: 6.2584 - val_accuracy: 0.6363 - 42s/epoch - 424ms/step
# Epoch 57/500
# 100/100 - 45s - loss: 0.0158 - accuracy: 0.9970 - val_loss: 13.7872 - val_accuracy: 0.4062 - 45s/epoch - 455ms/step
# Epoch 58/500
# 100/100 - 46s - loss: 1.0257e-04 - accuracy: 1.0000 - val_loss: 11.8666 - val_accuracy: 0.5412 - 46s/epoch - 459ms/step
# Epoch 59/500
# 100/100 - 47s - loss: 2.9260e-04 - accuracy: 1.0000 - val_loss: 10.4796 - val_accuracy: 0.5950 - 47s/epoch - 473ms/step
# Epoch 60/500
# 100/100 - 51s - loss: 9.7943e-04 - accuracy: 0.9990 - val_loss: 9.1063 - val_accuracy: 0.6637 - 51s/epoch - 513ms/step
# Epoch 61/500
# 100/100 - 42s - loss: 0.0209 - accuracy: 0.9970 - val_loss: 3.0146 - val_accuracy: 0.7100 - 42s/epoch - 416ms/step
# Epoch 62/500
# 100/100 - 46s - loss: 6.3824e-04 - accuracy: 1.0000 - val_loss: 3.4594 - val_accuracy: 0.7350 - 46s/epoch - 461ms/step
# Epoch 63/500
# 100/100 - 45s - loss: 5.3423e-04 - accuracy: 1.0000 - val_loss: 1.8278 - val_accuracy: 0.7663 - 45s/epoch - 452ms/step
# Epoch 64/500
# 100/100 - 45s - loss: 4.6048e-06 - accuracy: 1.0000 - val_loss: 1.1422 - val_accuracy: 0.8087 - 45s/epoch - 450ms/step
# Epoch 65/500
# 100/100 - 49s - loss: 5.8460e-06 - accuracy: 1.0000 - val_loss: 0.6801 - val_accuracy: 0.8525 - 49s/epoch - 493ms/step
# Epoch 66/500
# 100/100 - 42s - loss: 4.3565e-04 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9737 - 42s/epoch - 424ms/step
# Epoch 67/500
# 100/100 - 42s - loss: 3.5235e-04 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9750 - 42s/epoch - 423ms/step
# Epoch 68/500
# 100/100 - 43s - loss: 2.1200e-06 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9825 - 43s/epoch - 434ms/step
# Epoch 69/500
# 100/100 - 54s - loss: 1.2475e-04 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9837 - 54s/epoch - 539ms/step
# Epoch 70/500
# 100/100 - 47s - loss: 1.0151e-04 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 0.9900 - 47s/epoch - 470ms/step
# Epoch 71/500
# 100/100 - 48s - loss: 1.8896e-06 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9925 - 48s/epoch - 483ms/step
# Epoch 72/500
# 100/100 - 52s - loss: 1.9493e-06 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 0.9962 - 52s/epoch - 516ms/step
# Epoch 73/500
# 100/100 - 55s - loss: 9.8019e-06 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9962 - 55s/epoch - 548ms/step
# Epoch 74/500
# 100/100 - 47s - loss: 9.8496e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9962 - 47s/epoch - 474ms/step
# Epoch 75/500
# 100/100 - 40s - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0767 - val_accuracy: 0.9812 - 40s/epoch - 401ms/step
# Epoch 76/500
# 100/100 - 44s - loss: 0.0403 - accuracy: 0.9940 - val_loss: 0.4307 - val_accuracy: 0.9488 - 44s/epoch - 442ms/step
# Epoch 77/500
# 100/100 - 51s - loss: 0.0032 - accuracy: 0.9980 - val_loss: 1.7460 - val_accuracy: 0.8500 - 51s/epoch - 513ms/step
# Epoch 78/500
# 100/100 - 50s - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.4979 - val_accuracy: 0.9388 - 50s/epoch - 505ms/step
# Epoch 79/500
# 100/100 - 47s - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.0158 - val_accuracy: 0.9937 - 47s/epoch - 466ms/step
# Epoch 80/500
# 100/100 - 49s - loss: 0.0273 - accuracy: 0.9920 - val_loss: 0.0106 - val_accuracy: 0.9962 - 49s/epoch - 494ms/step
# Epoch 81/500
# 100/100 - 42s - loss: 0.0061 - accuracy: 0.9970 - val_loss: 0.0139 - val_accuracy: 0.9962 - 42s/epoch - 425ms/step
# Epoch 82/500
# 100/100 - 48s - loss: 0.0021 - accuracy: 0.9990 - val_loss: 0.0799 - val_accuracy: 0.9812 - 48s/epoch - 482ms/step
# Epoch 83/500
# 100/100 - 48s - loss: 8.8118e-05 - accuracy: 1.0000 - val_loss: 0.0375 - val_accuracy: 0.9925 - 48s/epoch - 481ms/step
# Epoch 84/500
# 100/100 - 46s - loss: 7.5954e-05 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9962 - 46s/epoch - 463ms/step
# Epoch 85/500
# 100/100 - 52s - loss: 0.0175 - accuracy: 0.9970 - val_loss: 3.6740 - val_accuracy: 0.7650 - 52s/epoch - 517ms/step
# Epoch 86/500
# 100/100 - 49s - loss: 0.0129 - accuracy: 0.9980 - val_loss: 0.1300 - val_accuracy: 0.9675 - 49s/epoch - 487ms/step
# Epoch 87/500
# 100/100 - 47s - loss: 0.0139 - accuracy: 0.9970 - val_loss: 33.7283 - val_accuracy: 0.3512 - 47s/epoch - 467ms/step
# Epoch 88/500
# 100/100 - 40s - loss: 1.3093e-04 - accuracy: 1.0000 - val_loss: 17.4754 - val_accuracy: 0.4787 - 40s/epoch - 399ms/step
# Epoch 89/500
# 100/100 - 47s - loss: 0.0098 - accuracy: 0.9980 - val_loss: 9.3768 - val_accuracy: 0.5337 - 47s/epoch - 467ms/step
# Epoch 90/500
# 100/100 - 48s - loss: 1.2855e-04 - accuracy: 1.0000 - val_loss: 6.7797 - val_accuracy: 0.6562 - 48s/epoch - 481ms/step
# Epoch 91/500
# 100/100 - 52s - loss: 4.3913e-05 - accuracy: 1.0000 - val_loss: 3.9159 - val_accuracy: 0.7412 - 52s/epoch - 521ms/step
# Epoch 92/500
# 100/100 - 45s - loss: 1.5335e-06 - accuracy: 1.0000 - val_loss: 1.6938 - val_accuracy: 0.8475 - 45s/epoch - 449ms/step
# Epoch 93/500
# 100/100 - 50s - loss: 4.4975e-06 - accuracy: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.9262 - 50s/epoch - 497ms/step
# Epoch 94/500
# 100/100 - 45s - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0012 - val_accuracy: 0.9987 - 45s/epoch - 451ms/step
# Epoch 95/500
# 100/100 - 40s - loss: 0.0719 - accuracy: 0.9910 - val_loss: 2.2211 - val_accuracy: 0.8825 - 40s/epoch - 401ms/step
# Epoch 96/500
# 100/100 - 47s - loss: 0.0193 - accuracy: 0.9980 - val_loss: 8.4211 - val_accuracy: 0.5312 - 47s/epoch - 470ms/step
# Epoch 97/500
# 100/100 - 41s - loss: 0.0366 - accuracy: 0.9980 - val_loss: 0.0050 - val_accuracy: 0.9987 - 41s/epoch - 406ms/step
# Epoch 98/500
# 100/100 - 47s - loss: 0.0222 - accuracy: 0.9970 - val_loss: 0.7332 - val_accuracy: 0.8763 - 47s/epoch - 471ms/step
# Epoch 99/500
# 100/100 - 51s - loss: 2.3927e-04 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 0.9525 - 51s/epoch - 507ms/step
# Epoch 100/500
# 100/100 - 45s - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.0658 - val_accuracy: 0.9837 - 45s/epoch - 449ms/step
# Epoch 101/500
# 100/100 - 51s - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0102 - val_accuracy: 0.9950 - 51s/epoch - 510ms/step
# Epoch 102/500
# 100/100 - 42s - loss: 0.0278 - accuracy: 0.9960 - val_loss: 4.4356 - val_accuracy: 0.8300 - 42s/epoch - 416ms/step
# Epoch 103/500
# 100/100 - 46s - loss: 8.0492e-05 - accuracy: 1.0000 - val_loss: 1.8846 - val_accuracy: 0.8650 - 46s/epoch - 464ms/step
# Epoch 104/500
# 100/100 - 46s - loss: 2.3438e-04 - accuracy: 1.0000 - val_loss: 1.5932 - val_accuracy: 0.8700 - 46s/epoch - 462ms/step
# Epoch 105/500
# 100/100 - 48s - loss: 1.6228e-04 - accuracy: 1.0000 - val_loss: 0.6778 - val_accuracy: 0.9250 - 48s/epoch - 477ms/step
# Epoch 106/500
# 100/100 - 53s - loss: 1.5755e-05 - accuracy: 1.0000 - val_loss: 0.1964 - val_accuracy: 0.9712 - 53s/epoch - 530ms/step
# Epoch 107/500
# 100/100 - 48s - loss: 9.0158e-05 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9912 - 48s/epoch - 477ms/step
# Epoch 108/500
# 100/100 - 47s - loss: 8.3124e-04 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 0.9987 - 47s/epoch - 467ms/step
# Epoch 109/500
# 100/100 - 54s - loss: 0.0049 - accuracy: 0.9970 - val_loss: 1.7339 - val_accuracy: 0.7400 - 54s/epoch - 538ms/step
# Epoch 110/500
# 100/100 - 49s - loss: 0.0175 - accuracy: 0.9960 - val_loss: 1.2726 - val_accuracy: 0.8225 - 49s/epoch - 488ms/step
# Epoch 111/500
# 100/100 - 46s - loss: 0.0022 - accuracy: 0.9990 - val_loss: 4.0004 - val_accuracy: 0.6675 - 46s/epoch - 463ms/step
# Epoch 112/500
# 100/100 - 43s - loss: 6.4089e-04 - accuracy: 1.0000 - val_loss: 2.4140 - val_accuracy: 0.7763 - 43s/epoch - 431ms/step
# Epoch 113/500
# 100/100 - 52s - loss: 2.4010e-05 - accuracy: 1.0000 - val_loss: 1.0359 - val_accuracy: 0.8525 - 52s/epoch - 519ms/step
# Epoch 114/500
# 100/100 - 45s - loss: 0.0130 - accuracy: 0.9950 - val_loss: 16.2797 - val_accuracy: 0.4988 - 45s/epoch - 455ms/step
# Epoch 115/500
# 100/100 - 52s - loss: 4.1531e-05 - accuracy: 1.0000 - val_loss: 7.9589 - val_accuracy: 0.6125 - 52s/epoch - 518ms/step
# Epoch 116/500
# 100/100 - 51s - loss: 0.0148 - accuracy: 0.9990 - val_loss: 3.7009 - val_accuracy: 0.6725 - 51s/epoch - 505ms/step
# Epoch 117/500
# 100/100 - 48s - loss: 0.0132 - accuracy: 0.9980 - val_loss: 1.4859 - val_accuracy: 0.7900 - 48s/epoch - 478ms/step
# Epoch 118/500
# 100/100 - 57s - loss: 0.0023 - accuracy: 0.9980 - val_loss: 0.4422 - val_accuracy: 0.9300 - 57s/epoch - 572ms/step
# Epoch 119/500
# 100/100 - 45s - loss: 1.3162e-04 - accuracy: 1.0000 - val_loss: 0.2734 - val_accuracy: 0.9475 - 45s/epoch - 452ms/step
# Epoch 120/500
# 100/100 - 46s - loss: 5.6119e-04 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 0.9975 - 46s/epoch - 456ms/step
# Epoch 121/500
# 100/100 - 54s - loss: 0.0167 - accuracy: 0.9970 - val_loss: 0.0338 - val_accuracy: 0.9900 - 54s/epoch - 536ms/step
# Epoch 122/500
# 100/100 - 52s - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.2693 - val_accuracy: 0.9613 - 52s/epoch - 517ms/step
# Epoch 123/500
# 100/100 - 51s - loss: 0.0212 - accuracy: 0.9970 - val_loss: 38.8825 - val_accuracy: 0.4963 - 51s/epoch - 505ms/step
# Epoch 124/500
# 100/100 - 45s - loss: 0.0012 - accuracy: 0.9990 - val_loss: 28.6556 - val_accuracy: 0.4712 - 45s/epoch - 445ms/step
# Epoch 125/500
# 100/100 - 40s - loss: 1.6037e-06 - accuracy: 1.0000 - val_loss: 14.6272 - val_accuracy: 0.5362 - 40s/epoch - 404ms/step
# Epoch 126/500
# 100/100 - 46s - loss: 1.2841e-04 - accuracy: 1.0000 - val_loss: 4.9903 - val_accuracy: 0.6737 - 46s/epoch - 461ms/step
# Epoch 127/500
# 100/100 - 48s - loss: 4.4687e-06 - accuracy: 1.0000 - val_loss: 1.6252 - val_accuracy: 0.8188 - 48s/epoch - 477ms/step
# Epoch 128/500
# 100/100 - 47s - loss: 2.6641e-06 - accuracy: 1.0000 - val_loss: 0.3877 - val_accuracy: 0.9275 - 47s/epoch - 465ms/step
# Epoch 129/500
# 100/100 - 50s - loss: 1.7504e-05 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9850 - 50s/epoch - 499ms/step
# Epoch 130/500
# 100/100 - 51s - loss: 1.1419e-04 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9837 - 51s/epoch - 511ms/step
# Epoch 131/500
# 100/100 - 46s - loss: 7.3809e-05 - accuracy: 1.0000 - val_loss: 0.0287 - val_accuracy: 0.9937 - 46s/epoch - 459ms/step
# Epoch 132/500
# 100/100 - 45s - loss: 3.9185e-06 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9975 - 45s/epoch - 447ms/step
# Epoch 133/500
# 100/100 - 49s - loss: 2.8656e-07 - accuracy: 1.0000 - val_loss: 6.0780e-04 - val_accuracy: 1.0000 - 49s/epoch - 491ms/step
# Epoch 134/500
# 100/100 - 47s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9737 - 47s/epoch - 472ms/step
# Epoch 135/500
# 100/100 - 43s - loss: 1.3014e-06 - accuracy: 1.0000 - val_loss: 0.0389 - val_accuracy: 0.9887 - 43s/epoch - 433ms/step
# Epoch 136/500
# 100/100 - 47s - loss: 4.7169e-07 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9962 - 47s/epoch - 475ms/step
# Epoch 137/500
# 100/100 - 54s - loss: 8.8229e-06 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 0.9975 - 54s/epoch - 538ms/step
# Epoch 138/500
# 100/100 - 57s - loss: 6.2791e-07 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9987 - 57s/epoch - 574ms/step
# Epoch 139/500
# 100/100 - 46s - loss: 1.2263e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9987 - 46s/epoch - 461ms/step
# Epoch 140/500
# 100/100 - 44s - loss: 2.6201e-07 - accuracy: 1.0000 - val_loss: 9.6204e-04 - val_accuracy: 1.0000 - 44s/epoch - 444ms/step
# Epoch 141/500
# 100/100 - 43s - loss: 1.2227e-06 - accuracy: 1.0000 - val_loss: 3.0618e-04 - val_accuracy: 1.0000 - 43s/epoch - 432ms/step
# Epoch 142/500
# 100/100 - 47s - loss: 1.6017e-05 - accuracy: 1.0000 - val_loss: 4.8232e-05 - val_accuracy: 1.0000 - 47s/epoch - 472ms/step
# Epoch 143/500
# 100/100 - 47s - loss: 1.9605e-06 - accuracy: 1.0000 - val_loss: 1.9331e-05 - val_accuracy: 1.0000 - 47s/epoch - 467ms/step
# Epoch 144/500
# 100/100 - 47s - loss: 4.2011e-06 - accuracy: 1.0000 - val_loss: 9.7096e-06 - val_accuracy: 1.0000 - 47s/epoch - 466ms/step
# Epoch 145/500
# 100/100 - 47s - loss: 4.5697e-07 - accuracy: 1.0000 - val_loss: 4.2630e-06 - val_accuracy: 1.0000 - 47s/epoch - 468ms/step
# Epoch 146/500
# 100/100 - 48s - loss: 1.1384e-07 - accuracy: 1.0000 - val_loss: 1.9544e-06 - val_accuracy: 1.0000 - 48s/epoch - 476ms/step
# Epoch 147/500
# 100/100 - 45s - loss: 2.0765e-07 - accuracy: 1.0000 - val_loss: 9.5708e-07 - val_accuracy: 1.0000 - 45s/epoch - 454ms/step
# Epoch 148/500
# 100/100 - 43s - loss: 1.8491e-06 - accuracy: 1.0000 - val_loss: 5.1161e-07 - val_accuracy: 1.0000 - 43s/epoch - 428ms/step
# Epoch 149/500
# 100/100 - 48s - loss: 3.1252e-06 - accuracy: 1.0000 - val_loss: 2.8607e-07 - val_accuracy: 1.0000 - 48s/epoch - 483ms/step
# Epoch 150/500
# 100/100 - 46s - loss: 0.0011 - accuracy: 0.9990 - val_loss: 0.0057 - val_accuracy: 0.9987 - 46s/epoch - 462ms/step
# Epoch 151/500
# 100/100 - 37s - loss: 0.0948 - accuracy: 0.9880 - val_loss: 55.5810 - val_accuracy: 0.3088 - 37s/epoch - 368ms/step
# Epoch 152/500
# 100/100 - 42s - loss: 0.0905 - accuracy: 0.9850 - val_loss: 13.6814 - val_accuracy: 0.4387 - 42s/epoch - 416ms/step
# Epoch 153/500
# 100/100 - 42s - loss: 0.0015 - accuracy: 0.9990 - val_loss: 18.4306 - val_accuracy: 0.3450 - 42s/epoch - 420ms/step
# Epoch 154/500
# 100/100 - 49s - loss: 0.0303 - accuracy: 0.9960 - val_loss: 31.8594 - val_accuracy: 0.3088 - 49s/epoch - 488ms/step
# Epoch 155/500
# 100/100 - 42s - loss: 2.1984e-04 - accuracy: 1.0000 - val_loss: 24.9417 - val_accuracy: 0.3125 - 42s/epoch - 418ms/step
# Epoch 156/500
# 100/100 - 47s - loss: 0.0118 - accuracy: 0.9960 - val_loss: 5.0012 - val_accuracy: 0.4812 - 47s/epoch - 467ms/step
# Epoch 157/500
# 100/100 - 47s - loss: 0.0076 - accuracy: 0.9970 - val_loss: 21.6179 - val_accuracy: 0.2475 - 47s/epoch - 465ms/step
# Epoch 158/500
# 100/100 - 45s - loss: 8.3176e-06 - accuracy: 1.0000 - val_loss: 28.9387 - val_accuracy: 0.2887 - 45s/epoch - 452ms/step
# Epoch 159/500
# 100/100 - 41s - loss: 4.7611e-04 - accuracy: 1.0000 - val_loss: 4.9367 - val_accuracy: 0.7725 - 41s/epoch - 408ms/step
# Epoch 160/500
# 100/100 - 48s - loss: 0.0053 - accuracy: 0.9970 - val_loss: 4.6791 - val_accuracy: 0.7412 - 48s/epoch - 485ms/step
# Epoch 161/500
# 100/100 - 54s - loss: 0.0045 - accuracy: 0.9990 - val_loss: 2.2464 - val_accuracy: 0.8188 - 54s/epoch - 544ms/step
# Epoch 162/500
# 100/100 - 56s - loss: 3.3969e-05 - accuracy: 1.0000 - val_loss: 1.6575 - val_accuracy: 0.8500 - 56s/epoch - 561ms/step
# Epoch 163/500
# 100/100 - 55s - loss: 6.4006e-06 - accuracy: 1.0000 - val_loss: 0.9593 - val_accuracy: 0.8888 - 55s/epoch - 552ms/step
# Epoch 164/500
# 100/100 - 52s - loss: 4.5855e-07 - accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.9337 - 52s/epoch - 525ms/step
# Epoch 165/500
# 100/100 - 47s - loss: 3.6031e-04 - accuracy: 1.0000 - val_loss: 0.1163 - val_accuracy: 0.9737 - 47s/epoch - 473ms/step
# Epoch 166/500
# 100/100 - 50s - loss: 2.5636e-05 - accuracy: 1.0000 - val_loss: 0.0446 - val_accuracy: 0.9862 - 50s/epoch - 501ms/step
# Epoch 167/500
# 100/100 - 47s - loss: 0.0143 - accuracy: 0.9970 - val_loss: 31.4689 - val_accuracy: 0.4450 - 47s/epoch - 475ms/step
# Epoch 168/500
# 100/100 - 46s - loss: 0.0159 - accuracy: 0.9970 - val_loss: 0.0257 - val_accuracy: 0.9937 - 46s/epoch - 460ms/step
# Epoch 169/500
# 100/100 - 36s - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.9061 - val_accuracy: 0.8625 - 36s/epoch - 358ms/step
# Epoch 170/500
# 100/100 - 55s - loss: 0.0075 - accuracy: 0.9990 - val_loss: 0.2418 - val_accuracy: 0.9525 - 55s/epoch - 548ms/step
# Epoch 171/500
# 100/100 - 60s - loss: 0.0207 - accuracy: 0.9960 - val_loss: 11.9047 - val_accuracy: 0.6975 - 60s/epoch - 598ms/step
# Epoch 172/500
# 100/100 - 54s - loss: 2.9974e-04 - accuracy: 1.0000 - val_loss: 7.2654 - val_accuracy: 0.7862 - 54s/epoch - 540ms/step
# Epoch 173/500
# 100/100 - 51s - loss: 1.4268e-04 - accuracy: 1.0000 - val_loss: 6.0920 - val_accuracy: 0.8163 - 51s/epoch - 510ms/step
# Epoch 174/500
# 100/100 - 48s - loss: 1.6564e-05 - accuracy: 1.0000 - val_loss: 3.4304 - val_accuracy: 0.8662 - 48s/epoch - 479ms/step
# Epoch 175/500
# 100/100 - 45s - loss: 7.1918e-06 - accuracy: 1.0000 - val_loss: 1.2216 - val_accuracy: 0.9175 - 45s/epoch - 449ms/step
# Epoch 176/500
# 100/100 - 46s - loss: 1.8552e-06 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9775 - 46s/epoch - 462ms/step
# Epoch 177/500
# 100/100 - 47s - loss: 3.3257e-04 - accuracy: 1.0000 - val_loss: 3.2322e-05 - val_accuracy: 1.0000 - 47s/epoch - 469ms/step
# Epoch 178/500
# 100/100 - 44s - loss: 2.7013e-06 - accuracy: 1.0000 - val_loss: 1.7073e-05 - val_accuracy: 1.0000 - 44s/epoch - 435ms/step
# Epoch 179/500
# 100/100 - 47s - loss: 5.9359e-07 - accuracy: 1.0000 - val_loss: 9.9181e-06 - val_accuracy: 1.0000 - 47s/epoch - 466ms/step
# Epoch 180/500
# 100/100 - 56s - loss: 3.6088e-06 - accuracy: 1.0000 - val_loss: 6.7780e-06 - val_accuracy: 1.0000 - 56s/epoch - 557ms/step
# Epoch 181/500
# 100/100 - 51s - loss: 0.0247 - accuracy: 0.9970 - val_loss: 0.8198 - val_accuracy: 0.9000 - 51s/epoch - 508ms/step
# Epoch 182/500
# 100/100 - 42s - loss: 0.0073 - accuracy: 0.9990 - val_loss: 53.9751 - val_accuracy: 0.3650 - 42s/epoch - 425ms/step
# Epoch 183/500
# 100/100 - 52s - loss: 0.0388 - accuracy: 0.9930 - val_loss: 88.0250 - val_accuracy: 0.3988 - 52s/epoch - 517ms/step

# %%
def plot_all(history):
    """
    The plot_all() function takes the history of the trained model
    and create two plots for accuracy and loss of both training and validation.
    The plots are saved as png files

    Args:
        history: The history to use and plot

    """
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model_custom_five_accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.savefig("plot_accuracy_mobile_custom_five.png")
    plt.show()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model_custom_one_2loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.savefig("plot_loss_mobile_custom_five.png")
    plt.show()
    

plot_all(history)
model.save("Trained_Mobile_Custom_Five_Model")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 44). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Trained_Mobile_Custom_Five_Model\assets
# INFO:tensorflow:Assets written to: Trained_Mobile_Custom_Five_Model\assets

# %%
test_labels = test_batches.classes
predictions = model.predict(x=test_batches, verbose=0)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true=test_labels, y_pred=predictions.argmax(axis=1))

# %%
test_batches.class_indices
# Out:
# {'0': 0, '1': 1, '2': 2, '3': 3}

# %%
from matplotlib import pyplot as plt
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.savefig("confusion_mobile_custom_five.png")
    

cm_plot_labels = ['Asparagus', 'BrusselSprouts', 'Celery', 'SliverBeet']
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[150   0   0   0]
#  [  0 150   0   0]
#  [  1   0 149   0]
#  [  0   0  18 132]]
